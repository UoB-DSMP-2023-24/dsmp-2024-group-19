# %% [markdown]
# # import tapes and 15s features

# %%
import pandas as pd
import numpy as np

# get lob data
raw_lob_data = pd.read_csv("final_eval_60.csv", index_col=0)
raw_lob_data = raw_lob_data.fillna(method = "ffill")
lob_data = []
for day in raw_lob_data["DAY"].unique():
    df = raw_lob_data[raw_lob_data["DAY"] == day]
    df.index = df["ENDT"]
    df = df.drop(columns = ["ENDT"])
    lob_data.append(df)

print(list(lob_data[0]))
lob_data = lob_data
lob_data[0]
# Out:
# ['TCAS_std', 'TCAS_mean', 'TCAS_close', 'TCAS_delta', 'TCAS_corr', 'TCBS_std', 'TCBS_mean', 'TCBS_close', 'TCBS_delta', 'TCBS_corr', 'ALPHA_std', 'ALPHA_mean', 'ALPHA_close', 'ALPHA_delta', 'ALPHA_corr', 'BETA_std', 'BETA_mean', 'BETA_close', 'BETA_delta', 'BETA_corr', 'ZETA_std', 'ZETA_mean', 'ZETA_close', 'ZETA_delta', 'ZETA_corr', 'WMP_std', 'WMP_delta', 'WMP_corr', 'AWS_std', 'AWS_mean', 'AWS_close', 'AWS_delta', 'AWS_corr', 'VOL_std', 'VOL_mean', 'VOL_close', 'VOL_delta', 'VOL_corr', 'GAP_std', 'GAP_mean', 'GAP_close', 'GAP_delta', 'GAP_corr', 'nUoD_std', 'nUoD_mean', 'nUoD_close', 'nUoD_delta', 'nUoD_corr', 'PSTD_std', 'PSTD_mean', 'PSTD_close', 'PSTD_delta', 'PSTD_corr', 'LOWIN_sum', 'HIWIN_sum', 'MP', 'HIBID', 'LOASK', 'AP', 'WBP', 'WAP', 'SPREAD', 'close_hibid', 'close_loask', 'MP_diff(y)', 'MP_perc(y)', 'DAY']
# C:\Users\wwden\AppData\Local\Temp\ipykernel_18500\2071172525.py:6: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   raw_lob_data = raw_lob_data.fillna(method = "ffill")
#            TCAS_std   TCAS_mean  TCAS_close  TCAS_delta  TCAS_corr  \
# ENDT
# 3660.0   173.435675  764.000000       404.0      -792.0  -0.275200
# 3720.0   176.232924  748.300000       254.0      -590.0  -0.281038
# 3780.0   178.931520  742.333333       486.0      -223.0  -0.302718
# 3840.0   179.974673  740.316667       588.0      -398.0  -0.330746
# 3900.0   178.095208  733.716667       590.0      -466.0  -0.317706
# ...             ...         ...         ...         ...        ...
# 30360.0  179.894290  836.666667       842.0       172.0  -0.069611
# 30420.0  179.192103  841.416667       955.0       282.0  -0.078436
# 30480.0  179.739357  840.883333       641.0      -432.0  -0.137357
# 30540.0  177.331300  837.900000       894.0       493.0  -0.092298
# 30600.0  171.121630  849.566667      1101.0       684.0  -0.126939
#
#            TCBS_std    TCBS_mean  TCBS_close  TCBS_delta  TCBS_corr  ...  \
# ENDT                                                                 ...
# 3660.0   428.585872  1370.983333       471.0      -820.0  -0.281637  ...
# 3720.0   438.983360  1359.900000       626.0     -1271.0  -0.328495  ...
# 3780.0   438.246068  1342.316667       842.0      -926.0  -0.326624  ...
# 3840.0   435.905336  1330.933333      1085.0      -258.0  -0.316472  ...
# 3900.0   436.393934  1328.033333      1169.0      -273.0  -0.325841  ...
# ...             ...          ...         ...         ...        ...  ...
# 30360.0  330.086495  1404.850000      1950.0       909.0   0.284667  ...
# 30420.0  326.716355  1410.300000      1368.0       474.0   0.251713  ...
# 30480.0  320.014817  1420.816667      1525.0       931.0   0.219803  ...
# 30540.0  302.631865  1431.233333      1219.0       473.0   0.133301  ...
# 30600.0  293.416035  1436.383333      1055.0       463.0   0.032535  ...
#
#          LOASK          AP         WBP         WAP  SPREAD  close_hibid  \
# ENDT
# 3660.0   300.0  257.488000  254.389776  263.023622    42.0        261.0
# 3720.0   258.0  254.805310  250.456057  259.973251     3.0        236.0
# 3780.0   259.0  257.831683  250.848848  262.843537     5.0        261.0
# 3840.0   268.0  262.461538  256.406330  269.501695     5.0        264.0
# 3900.0   266.0  262.118280  255.204082  268.119675     6.0        246.0
# ...        ...         ...         ...         ...     ...          ...
# 30360.0  294.0  289.822917  262.212719  310.930890     6.0        288.0
# 30420.0  301.0  293.675000  273.735082  312.932917     8.0        298.0
# 30480.0  292.0  289.133333  259.579163  309.648770     4.0        288.0
# 30540.0  296.0  290.021277  263.860664  312.310627     7.0        289.0
# 30600.0  292.0  288.635294  257.172753  306.591656     5.0        288.0
#
#          close_loask  MP_diff(y)  MP_perc(y)  DAY
# ENDT
# 3660.0         300.0       16.25    0.058244    0
# 3720.0         254.0      -22.50   -0.087719    0
# 3780.0         262.0        0.00    0.000000    0
# 3840.0         269.0        9.00    0.033898    0
# 3900.0         255.0       -2.50   -0.009506    0
# ...              ...         ...         ...  ...
# 30360.0        290.0       -4.50   -0.015464    0
# 30420.0        306.0        6.00    0.020202    0
# 30480.0        293.0       -7.00   -0.024138    0
# 30540.0        296.0        2.50    0.008547    0
# 30600.0        294.0       -3.00   -0.010363    0
#
# [450 rows x 67 columns]

# %% [markdown]
# # build trading environment with simple agent

# %%
class Mean_Rev():
    def __init__(self, training_data, test_data):
        median = training_data["AP"].mean()

        self.indicators = pd.DataFrame(index = test_data.index)
        self.indicators["IND"] = 0
        
        for index in test_data.index:
            if median < test_data.loc[index,"close_hibid"]: # if the highest bid is > median it is a high price to sell
                self.indicators.loc[index,"IND"] = -1
            elif median > test_data.loc[index,"close_loask"]: # if the lowest ask is < median it is a low price to buy
                self.indicators.loc[index,"IND"] = 1
            else:
                pass

    def action(self, time_i):
        return self.indicators.loc[time_i]["IND"]

def evaluate_day(training_data, test_data, agent, starting_cash):
    comm_perc = 0.001

    trader = agent(training_data, test_data)

    agent_value = []
    agent_cash = []
    num_trades = 0

    cash = starting_cash
    assets = 0
    for i, row in test_data.iterrows():
        action = trader.action(i)

        if action == 1:
            if cash >= row["close_loask"]:
                cash -= row["close_loask"]
                assets += 1
                num_trades += 1
                cash -= row["close_loask"] * comm_perc

        elif action == -1:
            if assets > 0:
                assets -= 1
                cash += row["close_hibid"]
                num_trades += 1
                cash -= row["close_hibid"] * comm_perc
        else:
            pass

        agent_value.append(cash + assets * row["AP"])
        agent_cash.append(cash)

    return agent_value, agent_cash, num_trades


def trading_env(level2_data: list[pd.DataFrame], agent):
    N = len(level2_data)
    starting_cash = 1_000

    buy_and_hold_profits = []
    agent_profits = []
    agent_sharpe = []
    agent_voli = []
    buy_and_hold_sharpe = []
    agent_daily_values = []
    agent_num_trades = []
    agent_time_in_market = []

    for day_i in range(1,N):
        print(f"Testing day {day_i}", end = "\r")
        prev_day = level2_data[day_i - 1]
        curr_day = level2_data[day_i]

        agent_value, agent_cash, num_trades = evaluate_day(prev_day, curr_day, agent, starting_cash)

        agent_num_trades.append(num_trades)
        agent_time_in_market.append(1 - (np.mean(np.array(agent_cash) / np.array(agent_value))))


        agent_value = np.array(agent_value)
        agent_return = (agent_value[-1] - starting_cash) / starting_cash
        agent_profits.append(agent_return)
        agent_voli.append(np.std(np.diff(agent_value) / agent_value[:-1]))
        day_return = (curr_day.iloc[-1]["AP"] / curr_day.iloc[0]["AP"]) - 1
        buy_and_hold_profits.append(day_return)
        agent_daily_values.append(agent_value)


        RF_rate = 0
        if agent_return == 0:
            agent_sharpe.append(0)
        else:
            agent_value = np.array(agent_value)
            ex_returns = (np.diff(agent_value) / agent_value[:-1]) - RF_rate
            agent_sharpe.append(np.mean(ex_returns) / np.std(ex_returns))

        ex_returns = curr_day["AP"].pct_change() - RF_rate
        buy_and_hold_sharpe.append(np.mean(ex_returns) / np.std(ex_returns))

    return [agent_profits, agent_sharpe, agent_daily_values, agent_num_trades, agent_time_in_market, agent_voli], [buy_and_hold_profits, buy_and_hold_sharpe]

#results = trading_env(lob_data, Mean_Rev)

# %% [markdown]
# # Visualisation Function

# %%
import matplotlib.pyplot as plt

def display_performance(results):

    # Assuming results is a list containing trader_performance, buy_and_hold_performance, sharpe_trader, and sharpe_buy_and_hold
    trader_performance = np.array(results[0][0])
    buy_and_hold_performance = np.array(results[1][0])
    sharpe_trader = results[0][1]
    sharpe_buy_and_hold = results[1][1]

    # Calculate cumulative returns
    trader_cumulative_returns = np.cumsum(trader_performance)
    buy_and_hold_cumulative_returns = np.cumsum(buy_and_hold_performance)

    # Create time axis
    x = np.arange(len(trader_performance))

    # Create cumulative Sharpe ratios
    cumulative_sharpe_trader = np.cumsum(sharpe_trader)
    cumulative_sharpe_buy_and_hold = np.cumsum(sharpe_buy_and_hold)

    # Create figure and axes
    fig, axs = plt.subplots(1, 2, figsize=(14, 6))

    # Plot cumulative returns on the first subplot
    axs[0].plot(x, trader_cumulative_returns, label='Trader', color='blue')
    axs[0].plot(x, buy_and_hold_cumulative_returns, label='Buy and Hold', color='red')
    axs[0].set_ylabel('Cumulative Returns')
    axs[0].set_xlabel('Days')
    axs[0].set_title('Cumulative Returns Over Time')
    axs[0].legend()

    # Plot cumulative Sharpe ratios on the second subplot
    axs[1].plot(x, cumulative_sharpe_trader, label='Trader', color='darkblue', linestyle='--')
    axs[1].plot(x, cumulative_sharpe_buy_and_hold, label='Buy and Hold', color='darkred', linestyle='--')
    axs[1].set_ylabel('Cumulative Sharpe Ratio')
    axs[1].set_xlabel('Days')
    axs[1].set_title('Cumulative Sharpe Ratio Over Time')
    axs[1].legend()

    # Adjust layout
    plt.tight_layout()

    # Show plot
    plt.show()

    trader_num_trades = results[0][3]
    trader_time_in_market = results[0][4]

    plt.figure(figsize=(14,3))
    plt.bar(x, trader_num_trades)
    plt.title('Number of Trades Over Time')
    plt.xlabel('Days')
    plt.ylabel('Number of Trades')
    plt.show()

    plt.figure(figsize=(14,3))
    plt.bar(x, trader_time_in_market)
    plt.title('Time Spent in Market Over Time')
    plt.xlabel('Days')
    plt.ylabel('Time in Market (days)')
    plt.show()


#display_performance(results)

# %% [markdown]
# # build arima and lstm agents

# %%
from statsmodels.tsa.arima.model import ARIMA

# ARMIMA

class ARMIA_agent():
    def __init__(self, training_data, test_data):
        self.indicators = pd.DataFrame(index = test_data.index)
        self.indicators["IND"] = 0

        model = ARIMA(training_data["AP"].to_numpy(), order=(1,0,1))
        result = model.fit()
        result2 = result.apply(test_data["AP"].to_numpy(), refit=False)
        pred2 = np.array(result2.predict(start=0, end=len(test_data)-1))

        self.indicators["ARIMA_pred"] = pred2

        for index in test_data.index:
            if self.indicators.loc[index, "ARIMA_pred"] < test_data.loc[index,"close_hibid"]: # if the highest bid is > median it is a high price to sell
                self.indicators.loc[index,"IND"] = -1
            elif self.indicators.loc[index, "ARIMA_pred"] > test_data.loc[index,"close_loask"]: # if the lowest ask is < median it is a low price to buy
                self.indicators.loc[index,"IND"] = 1
            else:
                pass

    def action(self, index):
        return self.indicators.loc[index,"IND"]
    
#display_performance(trading_env(lob_data, ARMIA_agent))

# %% [markdown]
# # build classification agents

# %%
class train_GAP_agent():
    gap_val = 0
    def __init__(self, training_data, test_data):
        self.indicators = pd.DataFrame(index = test_data.index)
        self.indicators["IND"] = 0

        gap_optimal = train_GAP_agent.gap_val

        for index in test_data.index:
            if test_data.loc[index, "GAP_close"] > gap_optimal: # if the highest bid is > median it is a high price to sell
                self.indicators.loc[index,"IND"] = -1
            else: # if the lowest ask is < median it is a low price to buy
                self.indicators.loc[index,"IND"] = 1

    def action(self, index):
        return self.indicators.loc[index,"IND"]

class GAP_agent():
    def __init__(self, training_data, test_data):
        self.indicators = pd.DataFrame(index = test_data.index)
        self.indicators["IND"] = 0

        min_train = training_data["GAP_close"].min() // 1
        max_train = training_data["GAP_close"].max() // 1
        range = max_train - min_train
        n = 10
        split = range // n
        gap_values = np.arange(min_train, max_train, split)

        scores = []
        for gv in gap_values:
            train_GAP_agent.gap_val = gv
            results = evaluate_day(training_data, training_data, train_GAP_agent, 1_000)
            scores.append(results[0][-1])

        optimal_gap = gap_values[np.argmax(scores)]
        #print(min_train, optimal_gap, max_train)


        for index in test_data.index:
            if test_data.loc[index, "GAP_close"] > optimal_gap: # if the highest bid is > median it is a high price to sell
                self.indicators.loc[index,"IND"] = -1
            else: # if the lowest ask is < median it is a low price to buy
                self.indicators.loc[index,"IND"] = 1

    def action(self, index):
        return self.indicators.loc[index,"IND"]
    
#display_performance(trading_env(lob_data[:], GAP_agent))

# %%
class GAP_tree_agent():
    def __init__(self, training_data, test_data):
        self.indicators = pd.DataFrame(index = test_data.index)
        self.indicators["IND"] = 0

        gap_close_val = 44.38
        gap_mean_val = 15.17

        for index in test_data.index:
            if test_data.loc[index, "GAP_close"] <= gap_close_val:
                if test_data.loc[index, "GAP_mean"] <= gap_mean_val:
                    self.indicators.loc[index,"IND"] = 0
                else:
                    self.indicators.loc[index,"IND"] = 1
            else:
                self.indicators.loc[index,"IND"] = -1

    def action(self, index):
        return self.indicators.loc[index,"IND"]
    
#display_performance(trading_env(lob_data[:20], GAP_tree_agent))

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error

class DTR_agent():
    def __init__(self, training_data, test_data):
        self.indicators = pd.DataFrame(index = test_data.index)
        self.indicators["IND"] = 0

        x_features = ["GAP_close", "GAP_delta", "WMP_delta", "AWS_close",
                      "BETA_delta", "TCBS_close", "BETA_close", "ALPHA_delta",
                      "ALPHA_close",]
        
        y_feature = "MP"

        X_train = training_data[x_features]
        y_train = training_data[y_feature]

        clf = DecisionTreeRegressor(max_leaf_nodes=4)
        clf.fit(X_train, y_train)

        print(list(X_train)[np.argmax(clf.feature_importances_)])

        print("Train ACC:", mean_absolute_error(clf.predict(X_train), y_train))
        
        self.indicators["DTR_pred"] = clf.predict(test_data[x_features])

        print("Test ACC:", mean_absolute_error(self.indicators["DTR_pred"], test_data[y_feature]))

        for index in test_data.index:
            if self.indicators.loc[index, "DTR_pred"] < test_data.loc[index,"close_hibid"]: # if the highest bid is > median it is a high price to sell
                self.indicators.loc[index,"IND"] = -1
            elif self.indicators.loc[index, "DTR_pred"] > test_data.loc[index,"close_loask"]: # if the lowest ask is < median it is a low price to buy
                self.indicators.loc[index,"IND"] = 1
            else:
                pass

    def action(self, index):
        return self.indicators.loc[index,"IND"]
    
class DTR_agent_level2():
    def __init__(self, training_data, test_data):
        self.indicators = pd.DataFrame(index = test_data.index)
        self.indicators["IND"] = 0

        x_features = []
        
        for f in list(training_data):
            if f.split("_")[0] in ["AWS", "TCBS", "TCAS", "ALPHA", "BETA", "ZETA"]:
                x_features.append(f)

        y_feature = "MP"

        X_train = training_data[x_features]
        y_train = training_data[y_feature]

        clf = DecisionTreeRegressor(max_leaf_nodes=4)
        clf.fit(X_train, y_train)

        print(list(X_train)[np.argmax(clf.feature_importances_)])

        print("Train ACC:", mean_absolute_error(clf.predict(X_train), y_train))
        
        self.indicators["DTR_pred"] = clf.predict(test_data[x_features])

        print("Test ACC:", mean_absolute_error(self.indicators["DTR_pred"], test_data[y_feature]))

        for index in test_data.index:
            if self.indicators.loc[index, "DTR_pred"] < test_data.loc[index,"close_hibid"]: # if the highest bid is > median it is a high price to sell
                self.indicators.loc[index,"IND"] = -1
            elif self.indicators.loc[index, "DTR_pred"] > test_data.loc[index,"close_loask"]: # if the lowest ask is < median it is a low price to buy
                self.indicators.loc[index,"IND"] = 1
            else:
                pass

    def action(self, index):
        return self.indicators.loc[index,"IND"]
    
class DTR_agent_level1():
    def __init__(self, training_data, test_data):
        self.indicators = pd.DataFrame(index = test_data.index)
        self.indicators["IND"] = 0

        x_features = []
        
        for f in list(training_data):
            if f.split("_")[0] in ["close", "VOL", "GAP"]:
                x_features.append(f)

        y_feature = "MP"

        X_train = training_data[x_features].copy()
        X_train["close_spread"] = X_train["close_hibid"] - X_train["close_loask"]
        y_train = training_data[y_feature]

        X_test = test_data[x_features].copy()
        X_test["close_spread"] = X_test["close_hibid"] - X_test["close_loask"]
        y_test = test_data[y_feature]

        clf = DecisionTreeRegressor(max_leaf_nodes=4)
        clf.fit(X_train, y_train)

        print(list(X_train)[np.argmax(clf.feature_importances_)])

        print("Train ACC:", mean_absolute_error(clf.predict(X_train), y_train))
        
        self.indicators["DTR_pred"] = clf.predict(X_test)

        print("Test ACC:", mean_absolute_error(self.indicators["DTR_pred"], y_test))

        for index in test_data.index:
            if self.indicators.loc[index, "DTR_pred"] < test_data.loc[index,"close_hibid"]: # if the highest bid is > median it is a high price to sell
                self.indicators.loc[index,"IND"] = -1
            elif self.indicators.loc[index, "DTR_pred"] > test_data.loc[index,"close_loask"]: # if the lowest ask is < median it is a low price to buy
                self.indicators.loc[index,"IND"] = 1
            else:
                pass

    def action(self, index):
        return self.indicators.loc[index,"IND"]
    
display_performance(trading_env(lob_data[:], DTR_agent_level1))
# Out:
# GAP_meanday 1
# Train ACC: 3.348580353529457
# Test ACC: 31.81971994097216
# close_hibid 2
# Train ACC: 5.044194376883098
# Test ACC: 11.672722769920506
# close_hibid 3
# Train ACC: 5.735077125992192
# Test ACC: 28.686599100834947
# close_hibid 4
# Train ACC: 4.7434773419190925
# Test ACC: 8.818312690277512
# close_hibid 5
# Train ACC: 4.362660639642267
# Test ACC: 5.6917746670555065
# close_hibid 6
# Train ACC: 4.915445761840498
# Test ACC: 11.13909263084451
# close_hibid 7
# Train ACC: 4.449701638426014
# Test ACC: 9.145587420646313
# close_hibid 8
# Train ACC: 6.024482406849493
# Test ACC: 6.141015108161026
# close_hibid 9
# Train ACC: 4.683438325787793
# Test ACC: 10.657432116685836
# close_hibid 10
# Train ACC: 5.348327352562646
# Test ACC: 15.839935019052653
# GAP_std day 11
# Train ACC: 4.203475134458598
# Test ACC: 12.204690960685923
# close_hibid 12
# Train ACC: 5.668642256562432
# Test ACC: 33.20514184539783
# close_hibid 13
# Train ACC: 4.825852096145239
# Test ACC: 8.451684158558464
# close_hibid 14
# Train ACC: 6.233226428915841
# Test ACC: 20.85933893195521
# close_hibid 15
# Train ACC: 4.951441111798254
# Test ACC: 9.680995842781535
# close_hibid 16
# Train ACC: 3.834167623201715
# Test ACC: 11.13572603823439
# close_hibid 17
# Train ACC: 5.786965541989517
# Test ACC: 23.63473064859076
# close_hibid 18
# Train ACC: 6.885758286016245
# Test ACC: 6.34539027807335
# close_hibid 19
# Train ACC: 4.502781259402954
# Test ACC: 13.98429695603084
# close_hibid 20
# Train ACC: 5.244125661375662
# Test ACC: 4.596766109221463
# close_hibid 21
# Train ACC: 3.645546077393921
# Test ACC: 6.734519057993564
# close_hibid 22
# Train ACC: 5.229110981884173
# Test ACC: 24.618620571809622
# close_hibid 23
# Train ACC: 6.337390237412626
# Test ACC: 6.427344774353689
# close_hibid 24
# Train ACC: 4.788685664291963
# Test ACC: 28.579001749781295
# close_hibid 25
# Train ACC: 5.429630010819906
# Test ACC: 7.681061295960206
# close_hibid 26
# Train ACC: 6.329676062519739
# Test ACC: 11.392867921579148
# close_hibid 27
# Train ACC: 4.1327469738629246
# Test ACC: 6.361923203602875
# close_hibid 28
# Train ACC: 5.3371033381651625
# Test ACC: 5.8806263628915385
# close_hibid 29
# Train ACC: 4.51052527112633
# Test ACC: 17.808892231578206
# close_hibid 30
# Train ACC: 4.217017840601669
# Test ACC: 8.643496381170072
# close_hibid 31
# Train ACC: 4.948426864376436
# Test ACC: 6.574017848337107
# close_hibid 32
# Train ACC: 5.199879751601948
# Test ACC: 21.238882104630587
# close_hibid 33
# Train ACC: 4.892309501512646
# Test ACC: 8.850979108944747
# close_hibid 34
# Train ACC: 4.601209941264988
# Test ACC: 27.536412358623377
# VOL_meanday 35
# Train ACC: 6.068060747156218
# Test ACC: 9.019163150492266
# close_hibid 36
# Train ACC: 5.964053179889342
# Test ACC: 5.67071485786426
# close_hibid 37
# Train ACC: 4.762249817648879
# Test ACC: 24.256945737274393
# close_hibid 38
# Train ACC: 6.653143197160484
# Test ACC: 11.60099595747596
# close_hibid 39
# Train ACC: 5.637920279337625
# Test ACC: 18.076217484270916
# close_hibid 40
# Train ACC: 5.857101548179067
# Test ACC: 30.685272079772055
# close_hibid 41
# Train ACC: 5.492231440609493
# Test ACC: 6.200550652468202
# close_hibid 42
# Train ACC: 5.596295889063187
# Test ACC: 18.47382219224985
# close_hibid 43
# Train ACC: 4.712622109051002
# Test ACC: 9.06645715645796
# VOL_std day 44
# Train ACC: 5.084186584930656
# Test ACC: 25.216812947401163
# close_hibid 45
# Train ACC: 6.13869497718657
# Test ACC: 13.414951156299848
# close_hibid 46
# Train ACC: 5.899062617751517
# Test ACC: 6.483701723548167
# close_hibid 47
# Train ACC: 5.938613148626735
# Test ACC: 10.967247164273475
# close_hibid 48
# Train ACC: 5.951300720738891
# Test ACC: 6.309924118479204
# GAP_closeay 49
# Train ACC: 4.37896347974544
# Test ACC: 12.388666553794792
# close_hibid 50
# Train ACC: 6.0310546209533005
# Test ACC: 8.895156695156697
# close_hibid 51
# Train ACC: 6.071710957222891
# Test ACC: 5.738728784728186
# close_hibid 52
# Train ACC: 5.391649768204663
# Test ACC: 8.609314015343463
# close_hibid 53
# Train ACC: 5.426324758531975
# Test ACC: 7.235267740535084
# close_hibid 54
# Train ACC: 5.771335540591943
# Test ACC: 22.61989608478069
# close_hibid 55
# Train ACC: 6.187718332132141
# Test ACC: 11.146222742040283
# close_hibid 56
# Train ACC: 5.815175689149488
# Test ACC: 7.062754575800431
# close_spread57
# Train ACC: 5.809499475562939
# Test ACC: 9.733797958883438
# close_hibid 58
# Train ACC: 5.525910811689705
# Test ACC: 7.7048184563974
# close_hibid 59
# Train ACC: 6.050801356287562
# Test ACC: 5.601197166851236
# close_hibid 60
# Train ACC: 5.069566841309825
# Test ACC: 6.388021507415342
# close_hibid 61
# Train ACC: 6.009496713718167
# Test ACC: 6.774282754496132
# close_loask 62
# Train ACC: 5.900400116652085
# Test ACC: 7.133698607118557
# close_hibid 63
# Train ACC: 5.165865971650578
# Test ACC: 7.91943805544815
# close_spread64
# Train ACC: 5.319061051952146
# Test ACC: 7.946620060562095
# close_hibid 65
# Train ACC: 5.861609093565615
# Test ACC: 21.372462967626003
# GAP_std day 66
# Train ACC: 5.2086914372116775
# Test ACC: 7.322125239567381
# close_hibid 67
# Train ACC: 5.718093168258549
# Test ACC: 6.422457669523454
# close_hibid 68
# Train ACC: 5.815463010606665
# Test ACC: 6.535472397936083
# GAP_std day 69
# Train ACC: 5.656076210233711
# Test ACC: 11.137289079910852
# close_hibid 70
# Train ACC: 5.747109408258834
# Test ACC: 7.326819923371645
# close_hibid 71
# Train ACC: 5.330558001640257
# Test ACC: 8.361027518547
# VOL_meanday 72
# Train ACC: 5.2679974167674635
# Test ACC: 9.261430001177445
# close_hibid 73
# Train ACC: 5.698172443319786
# Test ACC: 5.687138377680648
# GAP_meanday 74
# Train ACC: 5.442821239606955
# Test ACC: 8.297453703703699
# close_hibid 75
# Train ACC: 5.541730056724619
# Test ACC: 6.621521297549734
# close_hibid 76
# Train ACC: 5.017233027953959
# Test ACC: 20.312780949025132
# close_hibid 77
# Train ACC: 5.0643016538551135
# Test ACC: 6.3936177058880155
# GAP_meanday 78
# Train ACC: 5.355778899082569
# Test ACC: 10.072037402310574
# VOL_meanday 79
# Train ACC: 5.496573905486671
# Test ACC: 9.022792631694934
# GAP_std day 80
# Train ACC: 5.452668583852795
# Test ACC: 7.880026615684506
# close_hibid 81
# Train ACC: 5.0521803712683075
# Test ACC: 11.46579241548221
# close_hibid 82
# Train ACC: 5.920146971630082
# Test ACC: 7.7604647207554525
# close_hibid 83
# Train ACC: 5.463734586847948
# Test ACC: 8.556905281586065
# close_hibid 84
# Train ACC: 6.028078590213616
# Test ACC: 6.637334090531834
# close_hibid 85
# Train ACC: 5.6113815295777325
# Test ACC: 16.845161087107282
# close_hibid 86
# Train ACC: 6.0218249280683445
# Test ACC: 15.13962160302717
# close_hibid 87
# Train ACC: 6.221953748006379
# Test ACC: 8.971435489766085
# VOL_std day 88
# Train ACC: 5.109374800354924
# Test ACC: 9.72996875677807
# close_hibid 89
# Train ACC: 5.3934896445216625
# Test ACC: 5.904221063953007
# close_loask 90
# Train ACC: 5.517112142646626
# Test ACC: 8.242109539247474
# close_hibid 91
# Train ACC: 5.664077753680473
# Test ACC: 12.62685941043084
# close_hibid 92
# Train ACC: 6.344432220682221
# Test ACC: 7.989266381766381
# close_hibid 93
# Train ACC: 5.542820661861582
# Test ACC: 7.4936939729778596
# VOL_meanday 94
# Train ACC: 5.994860350546626
# Test ACC: 6.800210686877357
# close_hibid 95
# Train ACC: 5.6143944689591905
# Test ACC: 5.977196272424073
# VOL_meanday 96
# Train ACC: 5.615080818413226
# Test ACC: 8.254982619119613
# close_hibid 97
# Train ACC: 5.717517261939108
# Test ACC: 6.5642339874278
# close_hibid 98
# Train ACC: 5.176461223018928
# Test ACC: 6.7303046389100585
# close_loask 99
# Train ACC: 5.5583594484808865
# Test ACC: 6.230330270762057
# VOL_meanday 100
# Train ACC: 5.493658506959331
# Test ACC: 8.59110232263474
# close_hibid 101
# Train ACC: 5.4754875283446705
# Test ACC: 6.515646888384982
# close_loask 102
# Train ACC: 5.681032921810699
# Test ACC: 7.447200960219474
# close_loask 103
# Train ACC: 5.482169212167493
# Test ACC: 6.267052723685882
# close_hibid 104
# Train ACC: 5.12910894360351
# Test ACC: 6.277646320497681
# close_loask 105
# Train ACC: 5.688943297894517
# Test ACC: 5.7316632270168855
# close_hibid 106
# Train ACC: 5.477635773663171
# Test ACC: 5.905949537524881
# close_loask 107
# Train ACC: 5.5221756021756025
# Test ACC: 5.933429163429165
# close_hibid 108
# Train ACC: 5.393016852327905
# Test ACC: 5.409305133598193
# VOL_closeay 109
# Train ACC: 4.972830726005329
# Test ACC: 6.476496216893042
# VOL_closeay 110
# Train ACC: 5.280756179168461
# Test ACC: 6.20361568394244
# GAP_meanday 111
# Train ACC: 5.730876207729469
# Test ACC: 6.343841787439614
# close_loask 112
# Train ACC: 5.941335839829293
# Test ACC: 6.243945816948089
# close_loask 113
# Train ACC: 5.632029103760334
# Test ACC: 5.275663837382627
# close_loask 114
# Train ACC: 4.990012127011164
# Test ACC: 5.244918409924521
# close_loask 115
# Train ACC: 5.1775624122566075
# Test ACC: 6.0994650298073205
# close_loask 116
# Train ACC: 5.340343831092238
# Test ACC: 6.506542521821184
# GAP_closeay 117
# Train ACC: 5.879104814892738
# Test ACC: 6.0573661858787045
# close_hibid 118
# Train ACC: 5.992938137327321
# Test ACC: 6.071845443790666
# close_hibid 119
# Train ACC: 5.522008186218068
# Test ACC: 6.458838587318579
# close_hibid 120
# Train ACC: 5.657358232181762
# Test ACC: 5.236959850606911
# close_hibid 121
# Train ACC: 4.88870282460293
# Test ACC: 4.98566256320538
# close_loask 122
# Train ACC: 4.889042111359311
# Test ACC: 6.3123766029618595
# close_loask 123
# Train ACC: 5.964857767231916
# Test ACC: 6.106697218983461
# close_hibid 124
# Train ACC: 5.498113662054542
# Test ACC: 5.954524697902432

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

def eps_y_bool(arr, eps):
    return np.std([np.sum(arr > eps),np.sum(arr < -eps), np.sum( (arr < eps) & (arr > -eps) )])

def gen_y_bool(y, eps):
    if abs(y) < eps:
        return 0
    elif y > 0:
        return 1
    else:
        return -1

class DTC_agent():
    def __init__(self, training_data, test_data):
        self.indicators = pd.DataFrame(index = test_data.index)
        self.indicators["IND"] = 0

        x_features = ["GAP_close", "GAP_delta", "WMP_delta", "AWS_close",
                      "BETA_delta", "TCBS_close", "BETA_close", "ALPHA_delta",
                      "ALPHA_close"]

        x_features = list(training_data)
        x_features.remove("MP_perc(y)")
        x_features.remove("MP_diff(y)")

        y_feature = "MP"

        X_train = training_data[x_features]
        y_values = training_data[y_feature].pct_change()

        eps_values = np.arange(y_values.min(), y_values.max(), 0.01)

        eps_scores = []
        for eps in eps_values:
            eps_scores.append(eps_y_bool(y_values, eps))

        optimal_eps = eps_values[np.argmin(eps_scores)]
        #print(len(eps_values), optimal_eps)

        y_train = [gen_y_bool(val, optimal_eps) for val in y_values.to_numpy()]
        y_test = [gen_y_bool(val, optimal_eps) for val in test_data[y_feature].pct_change().to_numpy()]

        clf = DecisionTreeClassifier(max_leaf_nodes=8)
        clf.fit(X_train, y_train)

        print("Train ACC:", accuracy_score(clf.predict(X_train), y_train))
        
        self.indicators["IND"] = -1 * clf.predict(test_data[x_features])

        print("Test ACC:", accuracy_score(self.indicators["IND"], y_test))
        print(x_features[np.argmax(clf.feature_importances_)])


    def action(self, index):
        return self.indicators.loc[index,"IND"]

# %%
class Optimistic():
    def __init__(self, training_data, test_data):
        self.indicators = pd.DataFrame(index = test_data.index)
        self.indicators["IND"] = 0

        foo = False
        for i, row in test_data.iterrows():
            if foo:
                self.indicators.loc[i, "IND"] = (test_data.loc[i, "AP"] > test_data.loc[i - 60, "AP"]) * 2 - 1
            else:
                foo = True

    def action(self, index):
        return self.indicators.loc[index,"IND"]
    
class MA_10():
    def __init__(self, training_data, test_data):
        self.indicators = pd.DataFrame(index = test_data.index)
        self.indicators["IND"] = 0

        foo = False
        for index, row in test_data.iterrows():
            if foo:
                mean = test_data[test_data.index < index]["AP"].tail(10).mean()
                if mean < test_data.loc[index,"close_hibid"]: # if the highest bid is > median it is a high price to sell
                    self.indicators.loc[index,"IND"] = -1
                elif mean > test_data.loc[index,"close_loask"]: # if the lowest ask is < median it is a low price to buy
                    self.indicators.loc[index,"IND"] = 1
                else:
                    pass
                    
            else:
                foo = True


    def action(self, index):
        return self.indicators.loc[index,"IND"]
    
display_performance(trading_env(lob_data[:], MA_10))
# Out:
# Testing day 124

# %% [markdown]
# # compare all agents

# %%
agents = [MA_10, Optimistic, Mean_Rev, ARMIA_agent, DTR_agent, DTR_agent_level2, DTR_agent_level1]

compare_results = []

for ag in agents:
    print(ag.__name__)
    compare_results.append(trading_env(lob_data, ag))
# Out:
# MA_10
# Optimisticy 124
# Mean_Revday 124
# ARMIA_agent 124
# Testing day 58
# c:\Users\wwden\OneDrive\Documents\GitHub\dsmp-2024-group-19\venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\wwden\OneDrive\Documents\GitHub\dsmp-2024-group-19\venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# Testing day 62
# c:\Users\wwden\OneDrive\Documents\GitHub\dsmp-2024-group-19\venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\wwden\OneDrive\Documents\GitHub\dsmp-2024-group-19\venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# Testing day 68
# c:\Users\wwden\OneDrive\Documents\GitHub\dsmp-2024-group-19\venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# Testing day 80
# c:\Users\wwden\OneDrive\Documents\GitHub\dsmp-2024-group-19\venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# Testing day 92
# c:\Users\wwden\OneDrive\Documents\GitHub\dsmp-2024-group-19\venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# Testing day 111
# c:\Users\wwden\OneDrive\Documents\GitHub\dsmp-2024-group-19\venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# Testing day 119
# c:\Users\wwden\OneDrive\Documents\GitHub\dsmp-2024-group-19\venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\wwden\OneDrive\Documents\GitHub\dsmp-2024-group-19\venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# DTR_agentay 124
# AWS_closeay 1
# Train ACC: 6.347325376506452
# Test ACC: 18.266490907301833
# WMP_deltaay 2
# Train ACC: 5.415229471161028
# Test ACC: 15.820877871689891
# AWS_closeay 3
# Train ACC: 8.578092380970432
# Test ACC: 42.69854721069357
# AWS_closeay 4
# Train ACC: 10.353850157077662
# Test ACC: 25.275976587996148
# AWS_closeay 5
# Train ACC: 7.363291331629822
# Test ACC: 10.611041793648559
# WMP_deltaay 6
# Train ACC: 9.769026175218007
# Test ACC: 18.264387930651356
# WMP_deltaay 7
# Train ACC: 5.943852116665876
# Test ACC: 13.001910649005364
# AWS_closeay 8
# Train ACC: 9.507390172122722
# Test ACC: 16.45718758811269
# WMP_deltaay 9
# Train ACC: 6.625882100417899
# Test ACC: 13.391467243387645
# ALPHA_close 10
# Train ACC: 7.873508316447147
# Test ACC: 29.609302776370612
# AWS_closeay 11
# Train ACC: 5.977734083306569
# Test ACC: 13.392904059256555
# AWS_closeay 12
# Train ACC: 6.434035626129345
# Test ACC: 48.98456646476254
# AWS_closeay 13
# Train ACC: 5.343806814743086
# Test ACC: 26.843922615325056
# AWS_closeay 14
# Train ACC: 8.187469073931561
# Test ACC: 50.308007341782535
# AWS_closeay 15
# Train ACC: 7.092312065637984
# Test ACC: 23.743816895315792
# WMP_deltaay 16
# Train ACC: 4.570372848670721
# Test ACC: 12.449698654166742
# WMP_deltaay 17
# Train ACC: 6.268819529078149
# Test ACC: 28.801580979373117
# AWS_closeay 18
# Train ACC: 12.687492126281036
# Test ACC: 27.26079231908335
# AWS_closeay 19
# Train ACC: 8.20155400941739
# Test ACC: 23.145352777192127
# AWS_closeay 20
# Train ACC: 12.189717366563132
# Test ACC: 17.93501360008479
# WMP_deltaay 21
# Train ACC: 4.279828956065161
# Test ACC: 8.667079407323136
# WMP_deltaay 22
# Train ACC: 6.670877616747184
# Test ACC: 27.526633022774337
# AWS_closeay 23
# Train ACC: 9.187574330980278
# Test ACC: 13.182637132347821
# WMP_deltaay 24
# Train ACC: 8.618791410930358
# Test ACC: 39.86298604895012
# AWS_closeay 25
# Train ACC: 9.115559703617643
# Test ACC: 10.665159769144148
# AWS_closeay 26
# Train ACC: 7.3868014074954145
# Test ACC: 25.455005993539114
# WMP_deltaay 27
# Train ACC: 5.0227998229025586
# Test ACC: 10.831815305778024
# ALPHA_close 28
# Train ACC: 7.774167141942044
# Test ACC: 9.360572621206815
# AWS_closeay 29
# Train ACC: 4.809227586206895
# Test ACC: 21.340097701149425
# AWS_closeay 30
# Train ACC: 8.555020615509306
# Test ACC: 19.182104058102293
# BETA_closey 31
# Train ACC: 5.403187893180019
# Test ACC: 7.3504665895929655
# AWS_closeay 32
# Train ACC: 5.797757437349741
# Test ACC: 25.959011769640806
# AWS_closeay 33
# Train ACC: 9.161788638379312
# Test ACC: 11.911920673505394
# ALPHA_delta 34
# Train ACC: 5.956283933348463
# Test ACC: 30.11780712797344
# WMP_deltaay 35
# Train ACC: 10.852536768277282
# Test ACC: 42.448737784383425
# AWS_closeay 36
# Train ACC: 6.587412826566378
# Test ACC: 7.838718869933475
# WMP_deltaay 37
# Train ACC: 4.993421320821623
# Test ACC: 25.808548704349047
# AWS_closeay 38
# Train ACC: 9.891046254479333
# Test ACC: 23.474325239537404
# BETA_closey 39
# Train ACC: 6.29539733618019
# Test ACC: 23.745793258801736
# AWS_closeay 40
# Train ACC: 8.176121761364508
# Test ACC: 33.14245831074978
# GAP_closeay 41
# Train ACC: 6.766522684692625
# Test ACC: 9.013214101078374
# BETA_closey 42
# Train ACC: 5.6167104473976845
# Test ACC: 26.47116402918005
# BETA_closey 43
# Train ACC: 5.236243468909628
# Test ACC: 13.356372423858346
# ALPHA_delta 44
# Train ACC: 5.774413592750955
# Test ACC: 29.56659527762408
# AWS_closeay 45
# Train ACC: 7.089850360860424
# Test ACC: 24.774153350493226
# GAP_closeay 46
# Train ACC: 5.851888266417678
# Test ACC: 6.765654325703346
# BETA_deltay 47
# Train ACC: 6.253050472040668
# Test ACC: 11.952223493100945
# AWS_closeay 48
# Train ACC: 6.920609959130971
# Test ACC: 8.333944628003675
# GAP_closeay 49
# Train ACC: 4.617402489680586
# Test ACC: 12.901036103840857
# AWS_closeay 50
# Train ACC: 6.890667948485574
# Test ACC: 21.968100305748237
# TCBS_closey 51
# Train ACC: 6.27242390001712
# Test ACC: 6.3679119157678485
# ALPHA_delta 52
# Train ACC: 5.669004316217977
# Test ACC: 10.1298476437642
# AWS_closeay 53
# Train ACC: 6.683208200585424
# Test ACC: 12.280639767148681
# AWS_closeay 54
# Train ACC: 5.870342417625084
# Test ACC: 24.086156844122723
# AWS_closeay 55
# Train ACC: 7.684473887064404
# Test ACC: 13.829401785714282
# AWS_closeay 56
# Train ACC: 6.224559730841392
# Test ACC: 8.876660222334472
# GAP_deltaay 57
# Train ACC: 5.845252476313522
# Test ACC: 12.645483419465968
# AWS_closeay 58
# Train ACC: 6.2883792142729344
# Test ACC: 11.891458860516838
# BETA_closey 59
# Train ACC: 6.259727917063367
# Test ACC: 5.840552240911172
# WMP_deltaay 60
# Train ACC: 5.252854602181696
# Test ACC: 6.38026659844077
# ALPHA_close 61
# Train ACC: 5.940642361111113
# Test ACC: 7.233344907407405
# GAP_deltaay 62
# Train ACC: 6.223712664277181
# Test ACC: 7.281892601126479
# WMP_deltaay 63
# Train ACC: 5.218825121238915
# Test ACC: 7.449334614938066
# GAP_closeay 64
# Train ACC: 5.606586712507764
# Test ACC: 8.161486488657541
# AWS_closeay 65
# Train ACC: 6.194147941448399
# Test ACC: 8.826462422982685
# WMP_deltaay 66
# Train ACC: 5.119235170129478
# Test ACC: 7.317506775067752
# WMP_deltaay 67
# Train ACC: 6.307983254595771
# Test ACC: 8.212883957365344
# AWS_closeay 68
# Train ACC: 6.406232427944728
# Test ACC: 7.3429537888639524
# TCBS_closey 69
# Train ACC: 5.856912562745896
# Test ACC: 12.19543671143671
# AWS_closeay 70
# Train ACC: 5.93907055549558
# Test ACC: 10.63731723383753
# WMP_deltaay 71
# Train ACC: 5.41652671213413
# Test ACC: 8.931288210936543
# TCBS_closey 72
# Train ACC: 5.408217169803376
# Test ACC: 8.571802408319652
# GAP_deltaay 73
# Train ACC: 6.145108410691795
# Test ACC: 5.946852039308986
# AWS_closeay 74
# Train ACC: 5.377773982221616
# Test ACC: 7.836690148507454
# AWS_closeay 75
# Train ACC: 5.82176024521292
# Test ACC: 8.738293512916941
# BETA_deltay 76
# Train ACC: 5.261154110767114
# Test ACC: 20.866099931200548
# GAP_deltaay 77
# Train ACC: 5.309309010093019
# Test ACC: 6.5727842518877475
# BETA_deltay 78
# Train ACC: 5.477883555054787
# Test ACC: 9.899959487240306
# ALPHA_close 79
# Train ACC: 5.568088894099052
# Test ACC: 9.540806565307898
# GAP_deltaay 80
# Train ACC: 5.789907752221007
# Test ACC: 8.281075575027375
# TCBS_closey 81
# Train ACC: 5.544135319740924
# Test ACC: 15.879409516153201
# TCBS_closey 82
# Train ACC: 6.118173997752541
# Test ACC: 8.461936150710098
# WMP_deltaay 83
# Train ACC: 5.714988078986097
# Test ACC: 7.298810607564258
# WMP_deltaay 84
# Train ACC: 6.493830517418964
# Test ACC: 6.962348497189176
# WMP_deltaay 85
# Train ACC: 6.174160976545351
# Test ACC: 22.065359350846673
# GAP_closeay 86
# Train ACC: 6.499764224653
# Test ACC: 19.390255727139948
# TCBS_closey 87
# Train ACC: 6.933228557504873
# Test ACC: 12.985864748677248
# WMP_deltaay 88
# Train ACC: 5.212955758962623
# Test ACC: 7.151285914060507
# WMP_deltaay 89
# Train ACC: 5.43546063826093
# Test ACC: 5.837825728374485
# ALPHA_close 90
# Train ACC: 5.57893051189506
# Test ACC: 8.898421964140185
# AWS_closeay 91
# Train ACC: 6.106245410229589
# Test ACC: 16.566799963903193
# TCBS_closey 92
# Train ACC: 6.4624607187782335
# Test ACC: 9.108053413049099
# WMP_deltaay 93
# Train ACC: 5.767531776617143
# Test ACC: 8.403117268300194
# TCBS_closey 94
# Train ACC: 5.815620413039768
# Test ACC: 6.69697175285885
# TCBS_closey 95
# Train ACC: 5.873338469630866
# Test ACC: 7.324704430830163
# AWS_closeay 96
# Train ACC: 5.556964846980975
# Test ACC: 7.29723214778053
# GAP_deltaay 97
# Train ACC: 6.008511702896813
# Test ACC: 8.197875126326172
# BETA_deltay 98
# Train ACC: 5.324953837895867
# Test ACC: 7.751097378779749
# BETA_closey 99
# Train ACC: 5.6132945943861055
# Test ACC: 6.097308884646169
# ALPHA_close 100
# Train ACC: 5.456663091886739
# Test ACC: 8.047408274622535
# TCBS_closey 101
# Train ACC: 5.6856631206251445
# Test ACC: 8.30337938843002
# WMP_deltaay 102
# Train ACC: 5.857477954144622
# Test ACC: 7.457611489040065
# GAP_closeay 103
# Train ACC: 5.6013177969486385
# Test ACC: 6.202660705727295
# WMP_deltaay 104
# Train ACC: 5.262961609129801
# Test ACC: 6.746925551275024
# AWS_closeay 105
# Train ACC: 5.955716985428051
# Test ACC: 5.866976775956284
# BETA_deltay 106
# Train ACC: 5.679573276625909
# Test ACC: 5.7418093212830055
# BETA_deltay 107
# Train ACC: 5.561996382929778
# Test ACC: 6.111672432443017
# GAP_closeay 108
# Train ACC: 5.546731759701399
# Test ACC: 5.2127527321929605
# BETA_closey 109
# Train ACC: 4.9866772975548965
# Test ACC: 5.717332746801571
# WMP_deltaay 110
# Train ACC: 5.299369408369409
# Test ACC: 6.263771464646464
# AWS_closeay 111
# Train ACC: 5.856610901941097
# Test ACC: 6.761436035809906
# AWS_closeay 112
# Train ACC: 6.1403565028161795
# Test ACC: 6.534061379928314
# AWS_closeay 113
# Train ACC: 5.737768302670963
# Test ACC: 5.345348790236851
# BETA_deltay 114
# Train ACC: 5.022764878968821
# Test ACC: 5.558918332479459
# GAP_closeay 115
# Train ACC: 5.20508180241995
# Test ACC: 6.12620447696394
# BETA_deltay 116
# Train ACC: 5.392896917896918
# Test ACC: 6.470852758352757
# GAP_closeay 117
# Train ACC: 5.880778796764197
# Test ACC: 6.296302742945077
# GAP_closeay 118
# Train ACC: 5.955748850916976
# Test ACC: 6.275600322710359
# ALPHA_close 119
# Train ACC: 5.71476871433367
# Test ACC: 6.02317433143113
# AWS_closeay 120
# Train ACC: 5.637818930041153
# Test ACC: 5.458685185185185
# ALPHA_close 121
# Train ACC: 5.062287524379109
# Test ACC: 5.216514650514491
# BETA_closey 122
# Train ACC: 4.872827040406294
# Test ACC: 6.267772213397976
# TCBS_closey 123
# Train ACC: 5.892872255633649
# Test ACC: 5.8443440491429755
# AWS_closeay 124
# Train ACC: 5.487793359763104
# Test ACC: 5.975275302075333
# DTR_agent_level2
# ALPHA_meany 1
# Train ACC: 3.5126803889879326
# Test ACC: 24.631865127179886
# TCBS_meanay 2
# Train ACC: 5.091257606231272
# Test ACC: 17.025709689341067
# AWS_deltaay 3
# Train ACC: 5.4962150433624
# Test ACC: 38.439917272412615
# BETA_stdday 4
# Train ACC: 6.962039328626284
# Test ACC: 19.348766815310306
# AWS_corrday 5
# Train ACC: 5.900601404629496
# Test ACC: 10.930235541611948
# TCAS_meanay 6
# Train ACC: 5.901002647149588
# Test ACC: 15.791119153957839
# ALPHA_meany 7
# Train ACC: 5.438972232043013
# Test ACC: 15.51708351992835
# AWS_closeay 8
# Train ACC: 7.151749244782198
# Test ACC: 9.50770931995794
# AWS_meanday 9
# Train ACC: 5.199072267661144
# Test ACC: 12.345834803274219
# ALPHA_meany 10
# Train ACC: 6.486952531936404
# Test ACC: 22.51445413105413
# ALPHA_meany 11
# Train ACC: 4.7517601748309035
# Test ACC: 14.631116545944396
# ZETA_meanay 12
# Train ACC: 5.654776137859044
# Test ACC: 44.89626315942149
# TCBS_meanay 13
# Train ACC: 4.994096089521378
# Test ACC: 24.99410144134283
# AWS_closeay 14
# Train ACC: 6.844612417792185
# Test ACC: 48.47166690289051
# ZETA_stdday 15
# Train ACC: 5.024120877248402
# Test ACC: 20.896700730402138
# TCBS_stdday 16
# Train ACC: 4.022353173026153
# Test ACC: 17.47023224158694
# ALPHA_meany 17
# Train ACC: 5.684869613366073
# Test ACC: 28.444710594315254
# ALPHA_stday 18
# Train ACC: 8.114479704528264
# Test ACC: 22.29400826458858
# AWS_meanday 19
# Train ACC: 4.595402837902839
# Test ACC: 27.23679376179376
# ZETA_meanay 20
# Train ACC: 6.469973224709409
# Test ACC: 6.246253870361919
# ZETA_meanay 21
# Train ACC: 3.4667316320288037
# Test ACC: 12.534506826742003
# ALPHA_meany 22
# Train ACC: 5.496602983797026
# Test ACC: 39.19606837606838
# TCBS_meanay 23
# Train ACC: 5.847431908643904
# Test ACC: 17.606602233002576
# TCBS_meanay 24
# Train ACC: 5.259950538051434
# Test ACC: 41.40460514124807
# ZETA_meanay 25
# Train ACC: 6.0501702410138956
# Test ACC: 9.276335988639595
# AWS_deltaay 26
# Train ACC: 6.282143452936624
# Test ACC: 16.49749224548575
# AWS_std day 27
# Train ACC: 4.219908954524145
# Test ACC: 10.78815420378184
# AWS_deltaay 28
# Train ACC: 5.673418134965599
# Test ACC: 13.286558624783877
# AWS_deltaay 29
# Train ACC: 4.86010260184248
# Test ACC: 20.940314117671793
# TCAS_stdday 30
# Train ACC: 4.430101466235209
# Test ACC: 14.233344678841487
# BETA_stdday 31
# Train ACC: 5.022070610922065
# Test ACC: 9.001686927904478
# ZETA_meanay 32
# Train ACC: 5.214722934569068
# Test ACC: 28.890213846523014
# ALPHA_meany 33
# Train ACC: 4.942018367171053
# Test ACC: 15.422137991668135
# AWS_std day 34
# Train ACC: 4.975128141330588
# Test ACC: 28.736873470522802
# ALPHA_meany 35
# Train ACC: 5.671332601129808
# Test ACC: 9.022992372234935
# TCAS_meanay 36
# Train ACC: 6.187360567169785
# Test ACC: 11.398324261399111
# TCAS_deltay 37
# Train ACC: 4.885862637787876
# Test ACC: 27.00131366681286
# AWS_deltaay 38
# Train ACC: 6.167969753311487
# Test ACC: 23.046233156383
# BETA_closey 39
# Train ACC: 5.91579125062334
# Test ACC: 24.617706083188047
# AWS_deltaay 40
# Train ACC: 6.666723682375621
# Test ACC: 33.300716674869776
# AWS_deltaay 41
# Train ACC: 5.789447921158713
# Test ACC: 9.11568197590166
# BETA_closey 42
# Train ACC: 5.703530059035441
# Test ACC: 26.98781077915465
# BETA_closey 43
# Train ACC: 4.9200803965197695
# Test ACC: 14.072069708852581
# ALPHA_stday 44
# Train ACC: 5.057211934121354
# Test ACC: 30.100698603737687
# ALPHA_stday 45
# Train ACC: 5.9368941823179116
# Test ACC: 25.521603552705244
# BETA_closey 46
# Train ACC: 6.022089856357547
# Test ACC: 6.766609609048558
# ALPHA_close 47
# Train ACC: 6.228899942281453
# Test ACC: 11.161832839210641
# AWS_corrday 48
# Train ACC: 6.685631503158676
# Test ACC: 7.693445512820518
# BETA_closey 49
# Train ACC: 4.465624260181608
# Test ACC: 12.088821798372877
# AWS_closeay 50
# Train ACC: 6.149805069715287
# Test ACC: 22.797654318505707
# AWS_deltaay 51
# Train ACC: 6.298857142857142
# Test ACC: 7.940242843576178
# ZETA_meanay 52
# Train ACC: 5.507767273576098
# Test ACC: 11.194168300653594
# TCBS_corray 53
# Train ACC: 5.792285611212228
# Test ACC: 8.012360879867543
# AWS_corrday 54
# Train ACC: 5.698539961395564
# Test ACC: 23.205597788227088
# BETA_meanay 55
# Train ACC: 6.139006584034001
# Test ACC: 10.495509959584455
# ALPHA_meany 56
# Train ACC: 6.022033828860773
# Test ACC: 9.875330348738737
# ALPHA_stday 57
# Train ACC: 5.7694077787060225
# Test ACC: 12.87376403972895
# BETA_corray 58
# Train ACC: 5.668949600897813
# Test ACC: 9.986504796709717
# TCAS_deltay 59
# Train ACC: 6.105059342974036
# Test ACC: 6.159970632316601
# TCBS_meanay 60
# Train ACC: 5.280976772804181
# Test ACC: 6.47519139912541
# ALPHA_meany 61
# Train ACC: 6.110688154811138
# Test ACC: 9.74503558381583
# TCBS_meanay 62
# Train ACC: 5.986075889340156
# Test ACC: 8.619626844266996
# ZETA_corray 63
# Train ACC: 5.183765060157291
# Test ACC: 7.994916206678467
# BETA_stdday 64
# Train ACC: 5.577547806596223
# Test ACC: 8.756270284982387
# AWS_corrday 65
# Train ACC: 5.999404870513622
# Test ACC: 10.508098107116949
# TCBS_deltay 66
# Train ACC: 5.1255832053251416
# Test ACC: 7.447972094214029
# TCBS_corray 67
# Train ACC: 6.173700933641568
# Test ACC: 8.320201157602739
# AWS_corrday 68
# Train ACC: 5.68485683531398
# Test ACC: 8.23162605481177
# AWS_corrday 69
# Train ACC: 5.749671552516399
# Test ACC: 12.049255907223467
# ZETA_stdday 70
# Train ACC: 5.824001479822011
# Test ACC: 9.359572254446523
# BETA_stdday 71
# Train ACC: 5.367009649412024
# Test ACC: 9.238737784371907
# BETA_stdday 72
# Train ACC: 5.252266167204221
# Test ACC: 8.346814482679369
# AWS_deltaay 73
# Train ACC: 5.751037004808311
# Test ACC: 11.948625116924141
# ALPHA_stday 74
# Train ACC: 5.29760080434381
# Test ACC: 7.755559781919621
# AWS_corrday 75
# Train ACC: 5.69941757603048
# Test ACC: 9.174678550138225
# BETA_meanay 76
# Train ACC: 5.02709331371531
# Test ACC: 21.81378717424642
# TCAS_deltay 77
# Train ACC: 5.08650891638791
# Test ACC: 6.784884545554851
# BETA_corray 78
# Train ACC: 5.376583546922591
# Test ACC: 9.94083711546759
# AWS_deltaay 79
# Train ACC: 5.5281485798152445
# Test ACC: 12.676321289821285
# ALPHA_stday 80
# Train ACC: 5.628144920213886
# Test ACC: 9.984062951735359
# ALPHA_meany 81
# Train ACC: 5.182993827160493
# Test ACC: 18.260237654320996
# ALPHA_stday 82
# Train ACC: 6.017870082815735
# Test ACC: 8.209119133885432
# ZETA_meanay 83
# Train ACC: 5.594793288205195
# Test ACC: 7.7090128558310385
# TCAS_meanay 84
# Train ACC: 6.216012730592441
# Test ACC: 7.754713440901845
# ALPHA_stday 85
# Train ACC: 5.248126474666894
# Test ACC: 17.736261815874165
# TCBS_corray 86
# Train ACC: 6.023182093447083
# Test ACC: 19.404259229698777
# TCBS_corray 87
# Train ACC: 6.194852090582554
# Test ACC: 11.26052426623312
# AWS_meanday 88
# Train ACC: 5.087844590475807
# Test ACC: 7.000972381316022
# ZETA_corray 89
# Train ACC: 5.388004993757802
# Test ACC: 5.817967540574282
# TCAS_closey 90
# Train ACC: 5.462365055638598
# Test ACC: 9.530685102142503
# ALPHA_meany 91
# Train ACC: 5.758878513875535
# Test ACC: 14.77670397106564
# BETA_stdday 92
# Train ACC: 6.11086248324116
# Test ACC: 8.652395657889224
# BETA_stdday 93
# Train ACC: 5.2413108330639755
# Test ACC: 9.14867627344212
# ALPHA_close 94
# Train ACC: 5.762139782706793
# Test ACC: 6.904966833281268
# BETA_stdday 95
# Train ACC: 5.616948791648793
# Test ACC: 6.383126058201057
# AWS_deltaay 96
# Train ACC: 5.526030314762023
# Test ACC: 7.416401884700669
# ZETA_stdday 97
# Train ACC: 6.018510207141785
# Test ACC: 7.49480785296574
# ZETA_stdday 98
# Train ACC: 5.280894789332706
# Test ACC: 7.274513573011571
# BETA_closey 99
# Train ACC: 5.5826356592654935
# Test ACC: 6.153461947274102
# TCAS_meanay 100
# Train ACC: 5.49776208685008
# Test ACC: 8.166034010963928
# TCBS_meanay 101
# Train ACC: 5.474227738376676
# Test ACC: 8.106838521145264
# AWS_std day 102
# Train ACC: 5.807990794262469
# Test ACC: 7.723604956112174
# AWS_deltaay 103
# Train ACC: 5.549807614170484
# Test ACC: 6.3850761216696545
# TCAS_deltay 104
# Train ACC: 5.157448964142355
# Test ACC: 6.8113253753017
# AWS_closeay 105
# Train ACC: 5.910633378448054
# Test ACC: 5.849360337715906
# ZETA_meanay 106
# Train ACC: 5.577109134826527
# Test ACC: 14.228104622832884
# ZETA_meanay 107
# Train ACC: 5.467972789115645
# Test ACC: 5.898470143612997
# TCBS_deltay 108
# Train ACC: 5.552582417582418
# Test ACC: 5.285926996979629
# BETA_closey 109
# Train ACC: 5.00021319287685
# Test ACC: 5.648181590168046
# AWS_deltaay 110
# Train ACC: 5.302683944733047
# Test ACC: 6.342645422455389
# AWS_closeay 111
# Train ACC: 5.858001543209876
# Test ACC: 6.68852237654321
# AWS_closeay 112
# Train ACC: 6.097408960323007
# Test ACC: 6.594101638325957
# TCAS_stdday 113
# Train ACC: 5.823661515704526
# Test ACC: 6.547825107986397
# BETA_deltay 114
# Train ACC: 5.061998233796977
# Test ACC: 5.491537564341548
# AWS_deltaay 115
# Train ACC: 5.202263172674256
# Test ACC: 6.11760215523459
# ALPHA_corry 116
# Train ACC: 5.271818873668188
# Test ACC: 6.387385844748859
# BETA_meanay 117
# Train ACC: 5.9063238996709355
# Test ACC: 6.24466214305909
# ALPHA_corry 118
# Train ACC: 5.985031210986268
# Test ACC: 6.146354556803994
# TCBS_stdday 119
# Train ACC: 5.690257327496352
# Test ACC: 5.933876130915156
# AWS_deltaay 120
# Train ACC: 5.593482542318158
# Test ACC: 5.61844764232892
# ALPHA_stday 121
# Train ACC: 4.97996586134454
# Test ACC: 5.0268854166666666
# TCAS_corray 122
# Train ACC: 4.883716556166831
# Test ACC: 6.5863274086613055
# TCBS_corray 123
# Train ACC: 5.90733908393866
# Test ACC: 6.151700422047351
# BETA_closey 124
# Train ACC: 5.439440866826913
# Test ACC: 12.47665683753517
# DTR_agent_level1
# GAP_meanday 1
# Train ACC: 3.348580353529457
# Test ACC: 31.81971994097216
# close_hibid 2
# Train ACC: 5.044194376883098
# Test ACC: 11.672722769920506
# close_hibid 3
# Train ACC: 5.735077125992192
# Test ACC: 28.686599100834947
# close_hibid 4
# Train ACC: 4.7434773419190925
# Test ACC: 8.818312690277512
# close_hibid 5
# Train ACC: 4.362660639642267
# Test ACC: 5.6917746670555065
# close_hibid 6
# Train ACC: 4.915445761840498
# Test ACC: 11.13909263084451
# close_hibid 7
# Train ACC: 4.449701638426014
# Test ACC: 9.145587420646313
# close_hibid 8
# Train ACC: 6.024482406849493
# Test ACC: 6.141015108161026
# close_hibid 9
# Train ACC: 4.683438325787793
# Test ACC: 10.657432116685836
# close_hibid 10
# Train ACC: 5.348327352562646
# Test ACC: 15.839935019052653
# GAP_std day 11
# Train ACC: 4.203475134458598
# Test ACC: 12.204690960685923
# close_hibid 12
# Train ACC: 5.668642256562432
# Test ACC: 33.20514184539783
# close_hibid 13
# Train ACC: 4.825852096145239
# Test ACC: 8.451684158558464
# close_hibid 14
# Train ACC: 6.233226428915841
# Test ACC: 20.85933893195521
# close_hibid 15
# Train ACC: 4.951441111798254
# Test ACC: 9.680995842781535
# close_hibid 16
# Train ACC: 3.834167623201715
# Test ACC: 11.13572603823439
# close_hibid 17
# Train ACC: 5.786965541989517
# Test ACC: 23.63473064859076
# close_hibid 18
# Train ACC: 6.885758286016245
# Test ACC: 6.34539027807335
# close_hibid 19
# Train ACC: 4.502781259402954
# Test ACC: 13.98429695603084
# close_hibid 20
# Train ACC: 5.244125661375662
# Test ACC: 4.596766109221463
# close_hibid 21
# Train ACC: 3.645546077393921
# Test ACC: 6.734519057993564
# close_hibid 22
# Train ACC: 5.229110981884173
# Test ACC: 24.618620571809622
# close_hibid 23
# Train ACC: 6.337390237412626
# Test ACC: 6.427344774353689
# close_hibid 24
# Train ACC: 4.788685664291963
# Test ACC: 28.579001749781295
# close_hibid 25
# Train ACC: 5.429630010819906
# Test ACC: 7.681061295960206
# close_hibid 26
# Train ACC: 6.329676062519739
# Test ACC: 11.392867921579148
# close_hibid 27
# Train ACC: 4.1327469738629246
# Test ACC: 6.361923203602875
# close_hibid 28
# Train ACC: 5.3371033381651625
# Test ACC: 5.8806263628915385
# close_hibid 29
# Train ACC: 4.51052527112633
# Test ACC: 17.808892231578206
# close_hibid 30
# Train ACC: 4.217017840601669
# Test ACC: 8.643496381170072
# close_hibid 31
# Train ACC: 4.948426864376436
# Test ACC: 6.574017848337107
# close_hibid 32
# Train ACC: 5.199879751601948
# Test ACC: 21.238882104630587
# close_hibid 33
# Train ACC: 4.892309501512646
# Test ACC: 8.850979108944747
# close_hibid 34
# Train ACC: 4.601209941264988
# Test ACC: 27.536412358623377
# VOL_meanday 35
# Train ACC: 6.068060747156218
# Test ACC: 9.019163150492266
# close_hibid 36
# Train ACC: 5.964053179889342
# Test ACC: 5.67071485786426
# close_hibid 37
# Train ACC: 4.762249817648879
# Test ACC: 24.256945737274393
# close_hibid 38
# Train ACC: 6.653143197160484
# Test ACC: 11.60099595747596
# close_hibid 39
# Train ACC: 5.637920279337625
# Test ACC: 18.076217484270916
# close_hibid 40
# Train ACC: 5.857101548179067
# Test ACC: 30.685272079772055
# close_hibid 41
# Train ACC: 5.492231440609493
# Test ACC: 6.200550652468202
# close_hibid 42
# Train ACC: 5.596295889063187
# Test ACC: 18.47382219224985
# close_hibid 43
# Train ACC: 4.712622109051002
# Test ACC: 9.06645715645796
# VOL_std day 44
# Train ACC: 5.084186584930656
# Test ACC: 25.216812947401163
# close_hibid 45
# Train ACC: 6.13869497718657
# Test ACC: 13.414951156299848
# close_hibid 46
# Train ACC: 5.899062617751517
# Test ACC: 6.483701723548167
# close_hibid 47
# Train ACC: 5.938613148626735
# Test ACC: 10.967247164273475
# close_hibid 48
# Train ACC: 5.951300720738891
# Test ACC: 6.309924118479204
# GAP_closeay 49
# Train ACC: 4.37896347974544
# Test ACC: 12.388666553794792
# close_hibid 50
# Train ACC: 6.0310546209533005
# Test ACC: 8.895156695156697
# close_hibid 51
# Train ACC: 6.071710957222891
# Test ACC: 5.738728784728186
# close_hibid 52
# Train ACC: 5.391649768204663
# Test ACC: 8.609314015343463
# close_hibid 53
# Train ACC: 5.426324758531975
# Test ACC: 7.235267740535084
# close_hibid 54
# Train ACC: 5.771335540591943
# Test ACC: 22.61989608478069
# close_hibid 55
# Train ACC: 6.187718332132141
# Test ACC: 11.146222742040283
# close_hibid 56
# Train ACC: 5.815175689149488
# Test ACC: 7.062754575800431
# close_spread57
# Train ACC: 5.809499475562939
# Test ACC: 9.733797958883438
# close_hibid 58
# Train ACC: 5.525910811689705
# Test ACC: 7.7048184563974
# close_hibid 59
# Train ACC: 6.050801356287562
# Test ACC: 5.601197166851236
# close_hibid 60
# Train ACC: 5.069566841309825
# Test ACC: 6.388021507415342
# close_spread61
# Train ACC: 6.009496713718167
# Test ACC: 6.596028786242164
# close_loask 62
# Train ACC: 5.900400116652085
# Test ACC: 7.133698607118557
# close_hibid 63
# Train ACC: 5.165865971650578
# Test ACC: 7.91943805544815
# close_spread64
# Train ACC: 5.319061051952146
# Test ACC: 7.946620060562095
# close_hibid 65
# Train ACC: 5.861609093565615
# Test ACC: 21.372462967626003
# GAP_meanday 66
# Train ACC: 5.2086914372116775
# Test ACC: 6.587903017345158
# close_hibid 67
# Train ACC: 5.718093168258549
# Test ACC: 6.422457669523454
# close_hibid 68
# Train ACC: 5.815463010606665
# Test ACC: 6.535472397936083
# GAP_std day 69
# Train ACC: 5.656076210233711
# Test ACC: 11.137289079910852
# close_hibid 70
# Train ACC: 5.747109408258834
# Test ACC: 7.326819923371645
# close_hibid 71
# Train ACC: 5.330558001640257
# Test ACC: 8.361027518547
# VOL_meanday 72
# Train ACC: 5.2679974167674635
# Test ACC: 9.261430001177445
# close_hibid 73
# Train ACC: 5.698172443319786
# Test ACC: 5.687138377680648
# GAP_meanday 74
# Train ACC: 5.442821239606955
# Test ACC: 8.297453703703699
# close_hibid 75
# Train ACC: 5.541730056724619
# Test ACC: 6.621521297549734
# close_hibid 76
# Train ACC: 5.017233027953959
# Test ACC: 20.312780949025132
# close_hibid 77
# Train ACC: 5.0643016538551135
# Test ACC: 6.3936177058880155
# GAP_meanday 78
# Train ACC: 5.355778899082569
# Test ACC: 10.072037402310574
# VOL_meanday 79
# Train ACC: 5.496573905486671
# Test ACC: 9.022792631694934
# GAP_std day 80
# Train ACC: 5.452668583852795
# Test ACC: 7.880026615684506
# close_hibid 81
# Train ACC: 5.0521803712683075
# Test ACC: 11.46579241548221
# close_hibid 82
# Train ACC: 5.920146971630082
# Test ACC: 7.7604647207554525
# close_hibid 83
# Train ACC: 5.463734586847948
# Test ACC: 8.556905281586065
# close_hibid 84
# Train ACC: 6.028078590213616
# Test ACC: 6.637334090531834
# close_hibid 85
# Train ACC: 5.6113815295777325
# Test ACC: 16.845161087107282
# close_hibid 86
# Train ACC: 6.0218249280683445
# Test ACC: 15.13962160302717
# close_hibid 87
# Train ACC: 6.221953748006379
# Test ACC: 8.971435489766085
# VOL_std day 88
# Train ACC: 5.109374800354924
# Test ACC: 9.72996875677807
# close_hibid 89
# Train ACC: 5.3934896445216625
# Test ACC: 5.904221063953007
# close_loask 90
# Train ACC: 5.517112142646626
# Test ACC: 8.242109539247474
# close_hibid 91
# Train ACC: 5.664077753680473
# Test ACC: 12.62685941043084
# close_hibid 92
# Train ACC: 6.344432220682221
# Test ACC: 7.989266381766381
# close_hibid 93
# Train ACC: 5.542820661861582
# Test ACC: 7.4936939729778596
# VOL_meanday 94
# Train ACC: 5.994860350546626
# Test ACC: 6.800210686877357
# close_hibid 95
# Train ACC: 5.6143944689591905
# Test ACC: 5.977196272424073
# VOL_meanday 96
# Train ACC: 5.615080818413226
# Test ACC: 8.254982619119613
# close_hibid 97
# Train ACC: 5.717517261939108
# Test ACC: 6.5642339874278
# close_hibid 98
# Train ACC: 5.176461223018928
# Test ACC: 6.7303046389100585
# close_loask 99
# Train ACC: 5.5583594484808865
# Test ACC: 6.230330270762057
# VOL_meanday 100
# Train ACC: 5.493658506959331
# Test ACC: 8.59110232263474
# close_hibid 101
# Train ACC: 5.4754875283446705
# Test ACC: 6.515646888384982
# close_loask 102
# Train ACC: 5.681032921810699
# Test ACC: 7.447200960219474
# close_loask 103
# Train ACC: 5.482169212167493
# Test ACC: 6.267052723685882
# close_hibid 104
# Train ACC: 5.12910894360351
# Test ACC: 6.277646320497681
# close_loask 105
# Train ACC: 5.688943297894517
# Test ACC: 5.7316632270168855
# close_hibid 106
# Train ACC: 5.477635773663171
# Test ACC: 5.905949537524881
# close_loask 107
# Train ACC: 5.5221756021756025
# Test ACC: 6.095095830095832
# close_hibid 108
# Train ACC: 5.393016852327905
# Test ACC: 5.161749578042637
# VOL_closeay 109
# Train ACC: 4.972830726005329
# Test ACC: 6.476496216893042
# VOL_closeay 110
# Train ACC: 5.280756179168461
# Test ACC: 6.20361568394244
# GAP_meanday 111
# Train ACC: 5.730876207729469
# Test ACC: 6.343841787439614
# close_loask 112
# Train ACC: 5.941335839829293
# Test ACC: 6.243945816948089
# close_loask 113
# Train ACC: 5.632029103760334
# Test ACC: 5.275663837382627
# close_loask 114
# Train ACC: 4.990012127011164
# Test ACC: 5.244918409924521
# close_loask 115
# Train ACC: 5.1775624122566075
# Test ACC: 6.0994650298073205
# close_loask 116
# Train ACC: 5.340343831092238
# Test ACC: 6.506542521821184
# GAP_closeay 117
# Train ACC: 5.879104814892738
# Test ACC: 6.0573661858787045
# close_hibid 118
# Train ACC: 5.992938137327321
# Test ACC: 6.071845443790666
# close_hibid 119
# Train ACC: 5.522008186218068
# Test ACC: 6.458838587318579
# close_hibid 120
# Train ACC: 5.657358232181762
# Test ACC: 5.236959850606911
# close_hibid 121
# Train ACC: 4.88870282460293
# Test ACC: 4.98566256320538
# close_spread122
# Train ACC: 4.889042111359311
# Test ACC: 6.247709936295192
# close_loask 123
# Train ACC: 5.964857767231916
# Test ACC: 6.106697218983461
# close_hibid 124
# Train ACC: 5.498113662054542
# Test ACC: 5.954524697902432

# %%
import pandas as pd
import numpy as np

data = []

for i, results in enumerate(compare_results):
    name = agents[i].__name__
    avg_daily_profit = np.mean(results[0][0])
    avg_daily_voli = np.mean(results[0][-1])
    avg_daily_sharpe = np.mean(results[0][1])
    avg_daily_trades = np.mean(results[0][3])
    avg_daily_std_trades = np.std(results[0][3])
    avg_daily_tim = np.mean(results[0][4])
    avg_daily_std_tim = np.std(results[0][4])
    
    data.append([name, avg_daily_profit, avg_daily_voli, avg_daily_sharpe, avg_daily_trades, avg_daily_std_trades, avg_daily_tim, avg_daily_std_tim])

# Add row for BUY AND HOLD
avg_daily_profit_bh = np.mean(results[1][0])
avg_daily_sharpe_bh = np.mean(results[1][1])
data.append(["BUY AND HOLD", avg_daily_profit_bh, np.mean([np.std(lob_["AP"].pct_change()) for lob_ in lob_data]), avg_daily_sharpe_bh, np.nan, np.nan, np.nan, np.nan])

# Create DataFrame
df = pd.DataFrame(data, columns=['Agent', 'Avg Daily Profit', 'Avg Daily Voli', 'Avg Daily Sharpe', 'Avg Daily Trades', 'Avg Daily Std Trades', 'Avg Daily TIM', 'Avg Daily Std TIM'])

df["Profit/n_trades"] = df["Avg Daily Profit"] / df["Avg Daily Trades"]
df["AVG Daily Trading Frequency (min)"] = (8.5 * 60) / df["Avg Daily Trades"]

df
# Out:
#               Agent  Avg Daily Profit  Avg Daily Voli  Avg Daily Sharpe  \
# 0             MA_10          0.509577        0.002735          0.336690
# 1        Optimistic         -0.828523        0.026512         -0.148337
# 2          Mean_Rev          0.187583        0.005682          0.133897
# 3       ARMIA_agent          0.507561        0.002660          0.342918
# 4         DTR_agent          0.043626        0.010680          0.030464
# 5  DTR_agent_level2          0.039348        0.010737          0.028867
# 6  DTR_agent_level1          0.018360        0.011063          0.020271
# 7      BUY AND HOLD         -0.006681        0.013309          0.004922
#
#    Avg Daily Trades  Avg Daily Std Trades  Avg Daily TIM  Avg Daily Std TIM  \
# 0        130.169355             47.000810       0.081142           0.077641
# 1         72.975806             34.917521       0.089593           0.049039
# 2         52.193548             42.622249       0.352606           0.371796
# 3        131.798387             49.796842       0.074784           0.072239
# 4         27.588710             35.085153       0.704128           0.330006
# 5         25.395161             28.499524       0.710176           0.314520
# 6         24.314516             29.797804       0.744063           0.290589
# 7               NaN                   NaN            NaN                NaN
#
#    Profit/n_trades  AVG Daily Trading Frequency (min)
# 0         0.003915                           3.917973
# 1        -0.011353                           6.988618
# 2         0.003594                           9.771323
# 3         0.003851                           3.869547
# 4         0.001581                          18.485823
# 5         0.001549                          20.082566
# 6         0.000755                          20.975124
# 7              NaN                                NaN

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{llrrrrrrrrr}
# \toprule
#  & Agent & Avg Daily Profit & Avg Daily Voli & Avg Daily Sharpe & Avg Daily Trades & Avg Daily Std Trades & Avg Daily TIM & Avg Daily Std TIM & Profit/n_trades & AVG Daily Trading Frequency (min) \\
# \midrule
# 0 & MA_10 & 0.509577 & 0.002735 & 0.336690 & 130.169355 & 47.000810 & 0.081142 & 0.077641 & 0.003915 & 3.917973 \\
# 1 & Optimistic & -0.828523 & 0.026512 & -0.148337 & 72.975806 & 34.917521 & 0.089593 & 0.049039 & -0.011353 & 6.988618 \\
# 2 & Mean_Rev & 0.187583 & 0.005682 & 0.133897 & 52.193548 & 42.622249 & 0.352606 & 0.371796 & 0.003594 & 9.771323 \\
# 3 & ARMIA_agent & 0.507561 & 0.002660 & 0.342918 & 131.798387 & 49.796842 & 0.074784 & 0.072239 & 0.003851 & 3.869547 \\
# 4 & DTR_agent & 0.043626 & 0.010680 & 0.030464 & 27.588710 & 35.085153 & 0.704128 & 0.330006 & 0.001581 & 18.485823 \\
# 5 & DTR_agent_level2 & 0.039348 & 0.010737 & 0.028867 & 25.395161 & 28.499524 & 0.710176 & 0.314520 & 0.001549 & 20.082566 \\
# 6 & DTR_agent_level1 & 0.018360 & 0.011063 & 0.020271 & 24.314516 & 29.797804 & 0.744063 & 0.290589 & 0.000755 & 20.975124 \\
# 7 & BUY AND HOLD & -0.006681 & 0.013309 & 0.004922 & NaN & NaN & NaN & NaN & NaN & NaN \\
# \bottomrule
# \end{tabular}

# %%
class DTR_agent_FEAT_IMPORT():
    feat_importances = []
    feat_names = None
    feat_popup = []
    def __init__(self, training_data, test_data):
        self.indicators = pd.DataFrame(index = test_data.index)
        self.indicators["IND"] = 0

        x_features = []
        
        for f in list(training_data):
            if f.split("_")[0] in ["AWS", "TCBS", "TCAS", "ALPHA", "BETA", "ZETA", "GAP", "WMP", "VOL"]:
                x_features.append(f)

        y_feature = "MP"

        X_train = training_data[x_features]
        y_train = training_data[y_feature]

        clf = DecisionTreeRegressor(max_leaf_nodes=4)
        clf.fit(X_train, y_train)

        self.feat_importances.append(clf.feature_importances_)
        self.feat_names = x_features

        self.feat_popup.append(x_features[np.argmax(clf.feature_importances_)])

        print("Train ACC:", mean_absolute_error(clf.predict(X_train), y_train))
        
        self.indicators["DTR_pred"] = clf.predict(test_data[x_features])

        print("Test ACC:", mean_absolute_error(self.indicators["DTR_pred"], test_data[y_feature]))

        for index in test_data.index:
            if self.indicators.loc[index, "DTR_pred"] < test_data.loc[index,"close_hibid"]: # if the highest bid is > median it is a high price to sell
                self.indicators.loc[index,"IND"] = -1
            elif self.indicators.loc[index, "DTR_pred"] > test_data.loc[index,"close_loask"]: # if the lowest ask is < median it is a low price to buy
                self.indicators.loc[index,"IND"] = 1
            else:
                pass

    def action(self, index):
        return self.indicators.loc[index,"IND"]
    
results = trading_env(lob_data, DTR_agent_FEAT_IMPORT)
# Out:
# Train ACC: 3.480274922811411
# Test ACC: 31.923185504077253
# Train ACC: 4.648873717927949
# Test ACC: 15.215947741709074
# Train ACC: 5.4962150433624
# Test ACC: 38.439917272412615
# Train ACC: 6.962039328626284
# Test ACC: 19.348766815310306
# Train ACC: 5.740817305187488
# Test ACC: 14.885986538816164
# Train ACC: 5.901002647149588
# Test ACC: 15.791119153957839
# Train ACC: 5.278607676026613
# Test ACC: 12.946388794754364
# Train ACC: 6.830010358795492
# Test ACC: 9.978767981366566
# Train ACC: 4.988086817995924
# Test ACC: 14.969617304272557
# Train ACC: 5.983040068094132
# Test ACC: 26.126222777861614
# Train ACC: 4.27267692390966
# Test ACC: 15.40954084629019
# Train ACC: 5.2228040621266425
# Test ACC: 47.60205765068482
# Train ACC: 5.031607047922837
# Test ACC: 24.248593731804252
# Train ACC: 6.637747156170885
# Test ACC: 48.61702564102562
# Train ACC: 5.024120877248402
# Test ACC: 20.97905223284798
# Train ACC: 3.9349492151041265
# Test ACC: 18.860429369815577
# Train ACC: 5.678797515383724
# Test ACC: 28.668050766283507
# Train ACC: 10.234196748924754
# Test ACC: 13.977855763517518
# Train ACC: 4.494673403814061
# Test ACC: 32.502425208053154
# Train ACC: 6.539678934503354
# Test ACC: 6.579716912466583
# Train ACC: 3.4260685007040945
# Test ACC: 12.534506826742003
# Train ACC: 5.578571092989698
# Test ACC: 39.23495262704563
# Train ACC: 6.672860983314931
# Test ACC: 12.104070921768292
# Train ACC: 5.259950538051434
# Test ACC: 41.40460514124807
# Train ACC: 6.073090263627972
# Test ACC: 9.380142394488887
# Train ACC: 6.282143452936624
# Test ACC: 16.49749224548575
# Train ACC: 4.351163993964406
# Test ACC: 9.162932118598485
# Train ACC: 5.242491720241576
# Test ACC: 13.399670438218397
# Train ACC: 4.715260353603807
# Test ACC: 23.437493243175407
# Train ACC: 4.393611932732855
# Test ACC: 10.04543749268896
# Train ACC: 4.976129256711831
# Test ACC: 7.485493746844455
# Train ACC: 5.214722934569068
# Test ACC: 26.783477287383228
# Train ACC: 4.942018367171053
# Test ACC: 15.422137991668135
# Train ACC: 4.794467049977886
# Test ACC: 29.40407704309795
# Train ACC: 5.682876139848637
# Test ACC: 9.022992372234935
# Train ACC: 6.187360567169785
# Test ACC: 11.398324261399111
# Train ACC: 4.826260354121674
# Test ACC: 26.25496931141425
# Train ACC: 6.057851624849381
# Test ACC: 23.551949783621765
# Train ACC: 5.9490353185331895
# Test ACC: 22.966784573777364
# Train ACC: 5.696429900349299
# Test ACC: 44.051523980631366
# Train ACC: 5.353192620675345
# Test ACC: 9.412119925064701
# Train ACC: 5.5831787750361555
# Test ACC: 24.766880081215696
# Train ACC: 4.9200803965197695
# Test ACC: 14.072069708852581
# Train ACC: 4.852931833353634
# Test ACC: 28.809150951496953
# Train ACC: 5.767290280250432
# Test ACC: 24.81444669608616
# Train ACC: 5.878704577678434
# Test ACC: 6.687294403732312
# Train ACC: 6.221308656285368
# Test ACC: 11.77314850915194
# Train ACC: 6.555798987021209
# Test ACC: 9.949538778094325
# Train ACC: 4.570648758287673
# Test ACC: 13.406845700573154
# Train ACC: 5.857474546861837
# Test ACC: 16.445569413449242
# Train ACC: 6.273168724279836
# Test ACC: 6.217663796837775
# Train ACC: 5.509863433092535
# Test ACC: 8.169368249054006
# Train ACC: 5.446269799419766
# Test ACC: 12.474193607631957
# Train ACC: 5.698539961395564
# Test ACC: 23.205597788227088
# Train ACC: 6.119599704724865
# Test ACC: 12.929152306911023
# Train ACC: 5.817855442176871
# Test ACC: 8.193986678004533
# Train ACC: 5.711252829248122
# Test ACC: 16.212045789516903
# Train ACC: 5.657427797193308
# Test ACC: 11.338411802693681
# Train ACC: 5.986731492704826
# Test ACC: 5.822363950617283
# Train ACC: 5.270476744437417
# Test ACC: 6.178973820603034
# Train ACC: 6.110688154811138
# Test ACC: 9.74503558381583
# Train ACC: 5.999037854691685
# Test ACC: 6.300669718756077
# Train ACC: 5.183765060157291
# Test ACC: 9.490992282754544
# Train ACC: 5.577547806596223
# Test ACC: 8.756270284982387
# Train ACC: 6.0235890293487095
# Test ACC: 13.740442640644629
# Train ACC: 5.03274535860856
# Test ACC: 7.739188283065161
# Train ACC: 6.173700933641568
# Test ACC: 8.320201157602739
# Train ACC: 5.68485683531398
# Test ACC: 8.23162605481177
# Train ACC: 5.669890217877112
# Test ACC: 11.067203352957367
# Train ACC: 5.824001479822011
# Test ACC: 10.53266205657742
# Train ACC: 5.36553872053872
# Test ACC: 9.276077441077446
# Train ACC: 5.356604329973871
# Test ACC: 8.869592587408235
# Train ACC: 5.702620171500859
# Test ACC: 6.613224436945226
# Train ACC: 5.29760080434381
# Test ACC: 7.812802924643935
# Train ACC: 5.685195078191334
# Test ACC: 8.64191284665535
# Train ACC: 5.070033298953132
# Test ACC: 21.904895292910158
# Train ACC: 5.08650891638791
# Test ACC: 6.784884545554851
# Train ACC: 5.340502517080187
# Test ACC: 10.028608956257804
# Train ACC: 5.45594069853329
# Test ACC: 9.75382241215575
# Train ACC: 5.400199415604131
# Test ACC: 9.042962962962957
# Train ACC: 5.045891691233604
# Test ACC: 16.320227886900682
# Train ACC: 5.972123229220004
# Test ACC: 7.424437617340841
# Train ACC: 5.594793288205195
# Test ACC: 7.7090128558310385
# Train ACC: 6.290683542931546
# Test ACC: 7.509869196467359
# Train ACC: 5.248126474666894
# Test ACC: 17.736261815874165
# Train ACC: 6.0600181952107475
# Test ACC: 19.622265895299385
# Train ACC: 6.194852090582554
# Test ACC: 11.26052426623312
# Train ACC: 5.070989653019356
# Test ACC: 7.454735375403691
# Train ACC: 5.420548500881834
# Test ACC: 5.70786111111111
# Train ACC: 5.443850702442046
# Test ACC: 9.053489379184008
# Train ACC: 5.80617833080048
# Test ACC: 14.654393104709222
# Train ACC: 6.231029559225123
# Test ACC: 8.360902684438472
# Train ACC: 5.317009264462899
# Test ACC: 9.070275540212245
# Train ACC: 5.792768880704312
# Test ACC: 6.738512996669536
# Train ACC: 5.622391074549432
# Test ACC: 6.677709723967786
# Train ACC: 5.556891254924858
# Test ACC: 7.5814455217656755
# Train ACC: 5.937362781375271
# Test ACC: 7.489314859783469
# Train ACC: 5.280894789332706
# Test ACC: 7.274513573011571
# Train ACC: 5.559789629272387
# Test ACC: 6.2386667738391886
# Train ACC: 5.461652822848088
# Test ACC: 11.445300969512443
# Train ACC: 5.446499979746425
# Test ACC: 8.376613501032931
# Train ACC: 5.697347323110034
# Test ACC: 7.037919020715626
# Train ACC: 5.457611702489601
# Test ACC: 7.043199277348488
# Train ACC: 5.1553042359619115
# Test ACC: 6.636139536528653
# Train ACC: 5.881771094402675
# Test ACC: 5.815772765246449
# Train ACC: 5.577109134826527
# Test ACC: 14.228104622832884
# Train ACC: 5.467972789115645
# Test ACC: 5.898470143612997
# Train ACC: 5.500015015015014
# Test ACC: 5.146066066066067
# Train ACC: 4.946610817166373
# Test ACC: 5.850892857142858
# Train ACC: 5.302683944733047
# Test ACC: 6.342645422455389
# Train ACC: 5.762080537511924
# Test ACC: 6.681490250244691
# Train ACC: 6.1403565028161795
# Test ACC: 6.534061379928314
# Train ACC: 5.7500880331088675
# Test ACC: 5.490537768558602
# Train ACC: 5.033852346297069
# Test ACC: 5.898911177552187
# Train ACC: 5.162836109140458
# Test ACC: 5.874659161289597
# Train ACC: 5.271818873668188
# Test ACC: 6.387385844748859
# Train ACC: 5.835613326479157
# Test ACC: 6.2614784215808665
# Train ACC: 5.968934580973487
# Test ACC: 6.187362581739581
# Train ACC: 5.667563823877497
# Test ACC: 6.315800404962602
# Train ACC: 5.632153823026476
# Test ACC: 5.703762519495649
# Train ACC: 4.97996586134454
# Test ACC: 5.0268854166666666
# Train ACC: 4.883716556166831
# Test ACC: 6.5863274086613055
# Train ACC: 5.90733908393866
# Test ACC: 6.151700422047351
# Train ACC: 5.439440866826913
# Test ACC: 12.47665683753517

# %%
from collections import Counter
import matplotlib.pyplot as plt

# Example data
dtr_feat_imp = np.array(DTR_agent_FEAT_IMPORT.feat_importances)
x_features = []

for f in list(lob_data[0]):
    if f.split("_")[0] in ["AWS", "TCBS", "TCAS", "ALPHA", "BETA", "ZETA", "GAP", "WMP", "VOL"]:
        x_features.append(f)

# Plot bar chart for DTR_agent_FEAT_IMPORT.feat_importances
plt.figure(figsize=(10,4))
plt.bar(x_features, dtr_feat_imp.mean(axis=0))
plt.xticks(rotation=90)
plt.xlabel('Features')
plt.ylabel('Feature Importance')
plt.title('Feature Importance of DTR in trading simulation')
plt.show()

# Count occurrences of each element in DTR_agent_FEAT_IMPORT.feat_popup
counts = Counter(DTR_agent_FEAT_IMPORT.feat_popup)

# Extract elements and their corresponding counts
elements = list(counts.keys())
counts = list(counts.values())

# Plot bar chart for feat_popup
plt.figure(figsize=(10,6))
plt.bar(elements, counts)
plt.xlabel('Element')
plt.ylabel('Count')
plt.title('Count of Elements in DTR_agent_FEAT_IMPORT.feat_popup')
plt.xticks(rotation=90)
plt.show()

# %%
display_performance(results)

# %%
(8.5 * 60) / 590
# Out:
# 0.864406779661017

# %%
list(lob_data[0])
# Out:
# ['TCAS_std',
#  'TCAS_mean',
#  'TCAS_close',
#  'TCAS_delta',
#  'TCAS_corr',
#  'TCBS_std',
#  'TCBS_mean',
#  'TCBS_close',
#  'TCBS_delta',
#  'TCBS_corr',
#  'ALPHA_std',
#  'ALPHA_mean',
#  'ALPHA_close',
#  'ALPHA_delta',
#  'ALPHA_corr',
#  'BETA_std',
#  'BETA_mean',
#  'BETA_close',
#  'BETA_delta',
#  'BETA_corr',
#  'ZETA_std',
#  'ZETA_mean',
#  'ZETA_close',
#  'ZETA_delta',
#  'ZETA_corr',
#  'WMP_std',
#  'WMP_delta',
#  'WMP_corr',
#  'AWS_std',
#  'AWS_mean',
#  'AWS_close',
#  'AWS_delta',
#  'AWS_corr',
#  'VOL_std',
#  'VOL_mean',
#  'VOL_close',
#  'VOL_delta',
#  'VOL_corr',
#  'GAP_std',
#  'GAP_mean',
#  'GAP_close',
#  'GAP_delta',
#  'GAP_corr',
#  'nUoD_std',
#  'nUoD_mean',
#  'nUoD_close',
#  'nUoD_delta',
#  'nUoD_corr',
#  'PSTD_std',
#  'PSTD_mean',
#  'PSTD_close',
#  'PSTD_delta',
#  'PSTD_corr',
#  'LOWIN_sum',
#  'HIWIN_sum',
#  'MP',
#  'HIBID',
#  'LOASK',
#  'AP',
#  'WBP',
#  'WAP',
#  'SPREAD',
#  'close_hibid',
#  'close_loask',
#  'MP_diff(y)',
#  'MP_perc(y)',
#  'DAY']
