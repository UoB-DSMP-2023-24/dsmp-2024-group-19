# %% [markdown]
# Statistical Analysis lob bid, relative to tapes

# %%
import os
current_directory = os.getcwd()
parent_directory = os.path.dirname(current_directory)
os.chdir(parent_directory)
print("Working directory:", os.getcwd())
# Out:
# Working directory: c:\Users\benjo\OneDrive\Data Science Masters\DSMP\dsmp-2024-group-19

# %%
from fast_tools import *
import numpy as np
import matplotlib.pyplot as plt

# %%
index = 0
day = get_data(index,index+1)[0]
lob = np.abs(day[0])
time_arr = day[1]

time_diff = np.diff(time_arr)
twa = time_arr @ lob
wa = np.sum(lob, axis = 0)

plt.figure(figsize=(20,10))
plt.plot(twa, 'b')
plt.twinx()
plt.plot(wa, 'r')
plt.xlim(0,800)
plt.show()

plt.figure(figsize=(20,5))
plt.plot(day[2][:,1])
# Out:
# Time taken to reach each day: 0.23630499839782715

# %%
tapes_price = day[2][:,1]
tapes_volume = day[2][:,2]

prices = np.arange(1, 801)
volumes = np.zeros(800)

for price in prices:
    volumes[price-1] = np.sum(tapes_volume[tapes_price == price])

# %%
plt.figure(figsize=(20,5))
plt.plot(prices, volumes)

# %%
activity_ratio = (twa*(volumes+1))
plt.figure(figsize=(20,5))
plt.plot(activity_ratio)
plt.yscale("log")
plt.twinx()
plt.plot(twa, 'r')
plt.xlim(0,800)
# Out:
# (0.0, 800.0)
