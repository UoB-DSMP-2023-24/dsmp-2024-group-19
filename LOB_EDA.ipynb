# %%
import matplotlib.pyplot as plt
from tools import get_LOBs

# %%
LOB_df = get_LOBs(0)
# Out:
# Opening UoB_Set01_2025-01-02LOBs.txt

# %%
df = LOB_df[0]
df
# Out:
#                         Exchange  \
# combined_time
# 2025-01-02 08:00:00.000    Exch0
# 2025-01-02 08:00:00.279    Exch0
# 2025-01-02 08:00:01.333    Exch0
# 2025-01-02 08:00:01.581    Exch0
# 2025-01-02 08:00:01.643    Exch0
# ...                          ...
# 2025-01-02 16:29:59.542    Exch0
# 2025-01-02 16:29:59.573    Exch0
# 2025-01-02 16:29:59.635    Exch0
# 2025-01-02 16:29:59.759    Exch0
# 2025-01-02 16:29:59.945    Exch0
#
#                                                                        LOB  \
# combined_time
# 2025-01-02 08:00:00.000                             [[bid, []], [ask, []]]
# 2025-01-02 08:00:00.279                       [[bid, [[1, 6]]], [ask, []]]
# 2025-01-02 08:00:01.333               [[bid, [[1, 6]]], [ask, [[800, 1]]]]
# 2025-01-02 08:00:01.581               [[bid, [[1, 6]]], [ask, [[799, 1]]]]
# 2025-01-02 08:00:01.643               [[bid, [[1, 6]]], [ask, [[798, 1]]]]
# ...                                                                    ...
# ...

# %%
plt.figure(figsize = (20,6))
plt.plot(df.index, df["high_bid"], alpha = 0.6, label="high_bid")
plt.plot(df.index, df["low_ask"], alpha = 0.6,label="low_ask")
plt.plot(df.index, df["mid_price"], alpha = 0.6,label="mid_price")
plt.legend()
plt.ylim(230,350)
# Out:
# (230.0, 350.0)
