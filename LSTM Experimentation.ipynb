# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tools import *

# %% [markdown]
# code adapted from: https://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/

# %%
data = read_merged_data()
data = pd.DataFrame(data[0])[:600]
dataset = data.dropna()
# Out:
# Opening UoB_Set01_2025-01-02tapes.csv

# %%
dataset = dataset["Last Tapes Price"].values.reshape(-1,1)

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 187 93

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

# %%
# reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 185/185 - 3s - loss: 0.2676 - 3s/epoch - 17ms/step
# Epoch 2/100
# 185/185 - 2s - loss: 0.0794 - 2s/epoch - 9ms/step
# Epoch 3/100
# 185/185 - 2s - loss: 0.0311 - 2s/epoch - 9ms/step
# Epoch 4/100
# 185/185 - 2s - loss: 0.0281 - 2s/epoch - 9ms/step
# Epoch 5/100
# 185/185 - 2s - loss: 0.0275 - 2s/epoch - 9ms/step
# Epoch 6/100
# 185/185 - 2s - loss: 0.0271 - 2s/epoch - 10ms/step
# Epoch 7/100
# 185/185 - 2s - loss: 0.0264 - 2s/epoch - 10ms/step
# Epoch 8/100
# 185/185 - 2s - loss: 0.0261 - 2s/epoch - 9ms/step
# Epoch 9/100
# 185/185 - 2s - loss: 0.0257 - 2s/epoch - 9ms/step
# Epoch 10/100
# 185/185 - 2s - loss: 0.0252 - 2s/epoch - 10ms/step
# Epoch 11/100
# 185/185 - 2s - loss: 0.0249 - 2s/epoch - 11ms/step
# Epoch 12/100
# 185/185 - 2s - loss: 0.0244 - 2s/epoch - 8ms/step
# Epoch 13/100
# 185/185 - 2s - loss: 0.0240 - 2s/epoch - 8ms/step
# Epoch 14/100
# 185/185 - 1s - loss: 0.0238 - 1s/epoch - 7ms/step
# Epoch 15/100
# 185/185 - 1s - loss: 0.0236 - 1s/epoch - 6ms/step
# Epoch 16/100
# 185/185 - 1s - loss: 0.0232 - 1s/epoch - 7ms/step
# Epoch 17/100
# 185/185 - 1s - loss: 0.0231 - 1s/epoch - 7ms/step
# Epoch 18/100
# 185/185 - 1s - loss: 0.0227 - 1s/epoch - 7ms/step
# Epoch 19/100
# 185/185 - 1s - loss: 0.0228 - 1s/epoch - 7ms/step
# Epoch 20/100
# 185/185 - 1s - loss: 0.0225 - 1s/epoch - 6ms/step
# Epoch 21/100
# 185/185 - 1s - loss: 0.0222 - 1s/epoch - 7ms/step
# Epoch 22/100
# 185/185 - 1s - loss: 0.0226 - 1s/epoch - 7ms/step
# Epoch 23/100
# 185/185 - 1s - loss: 0.0222 - 1s/epoch - 8ms/step
# Epoch 24/100
# 185/185 - 1s - loss: 0.0222 - 1s/epoch - 6ms/step
# Epoch 25/100
# 185/185 - 1s - loss: 0.0220 - 1s/epoch - 6ms/step
# Epoch 26/100
# 185/185 - 1s - loss: 0.0223 - 1s/epoch - 7ms/step
# Epoch 27/100
# 185/185 - 1s - loss: 0.0220 - 1s/epoch - 6ms/step
# Epoch 28/100
# 185/185 - 1s - loss: 0.0220 - 1s/epoch - 6ms/step
# Epoch 29/100
# 185/185 - 1s - loss: 0.0221 - 1s/epoch - 6ms/step
# Epoch 30/100
# 185/185 - 1s - loss: 0.0220 - 1s/epoch - 6ms/step
# Epoch 31/100
# 185/185 - 2s - loss: 0.0220 - 2s/epoch - 9ms/step
# Epoch 32/100
# 185/185 - 1s - loss: 0.0219 - 1s/epoch - 8ms/step
# Epoch 33/100
# 185/185 - 1s - loss: 0.0220 - 1s/epoch - 6ms/step
# Epoch 34/100
# 185/185 - 1s - loss: 0.0220 - 1s/epoch - 6ms/step
# Epoch 35/100
# 185/185 - 1s - loss: 0.0219 - 1s/epoch - 7ms/step
# Epoch 36/100
# 185/185 - 1s - loss: 0.0222 - 1s/epoch - 7ms/step
# Epoch 37/100
# 185/185 - 1s - loss: 0.0218 - 1s/epoch - 6ms/step
# Epoch 38/100
# 185/185 - 2s - loss: 0.0220 - 2s/epoch - 9ms/step
# Epoch 39/100
# 185/185 - 2s - loss: 0.0221 - 2s/epoch - 9ms/step
# Epoch 40/100
# 185/185 - 2s - loss: 0.0219 - 2s/epoch - 9ms/step
# Epoch 41/100
# 185/185 - 1s - loss: 0.0215 - 1s/epoch - 7ms/step
# Epoch 42/100
# 185/185 - 1s - loss: 0.0218 - 1s/epoch - 7ms/step
# Epoch 43/100
# 185/185 - 1s - loss: 0.0220 - 1s/epoch - 6ms/step
# Epoch 44/100
# 185/185 - 1s - loss: 0.0218 - 1s/epoch - 6ms/step
# Epoch 45/100
# 185/185 - 1s - loss: 0.0218 - 1s/epoch - 6ms/step
# Epoch 46/100
# 185/185 - 1s - loss: 0.0219 - 1s/epoch - 6ms/step
# Epoch 47/100
# 185/185 - 1s - loss: 0.0219 - 1s/epoch - 7ms/step
# Epoch 48/100
# 185/185 - 1s - loss: 0.0220 - 1s/epoch - 6ms/step
# Epoch 49/100
# 185/185 - 1s - loss: 0.0219 - 1s/epoch - 6ms/step
# Epoch 50/100
# 185/185 - 1s - loss: 0.0219 - 1s/epoch - 6ms/step
# Epoch 51/100
# 185/185 - 1s - loss: 0.0222 - 1s/epoch - 6ms/step
# Epoch 52/100
# 185/185 - 1s - loss: 0.0220 - 1s/epoch - 8ms/step
# Epoch 53/100
# 185/185 - 2s - loss: 0.0222 - 2s/epoch - 9ms/step
# Epoch 54/100
# 185/185 - 2s - loss: 0.0220 - 2s/epoch - 9ms/step
# Epoch 55/100
# 185/185 - 2s - loss: 0.0219 - 2s/epoch - 9ms/step
# Epoch 56/100
# 185/185 - 1s - loss: 0.0220 - 1s/epoch - 7ms/step
# Epoch 57/100
# 185/185 - 1s - loss: 0.0218 - 1s/epoch - 7ms/step
# Epoch 58/100
# 185/185 - 1s - loss: 0.0217 - 1s/epoch - 7ms/step
# Epoch 59/100
# 185/185 - 1s - loss: 0.0218 - 1s/epoch - 6ms/step
# Epoch 60/100
# 185/185 - 1s - loss: 0.0218 - 1s/epoch - 8ms/step
# Epoch 61/100
# 185/185 - 1s - loss: 0.0218 - 1s/epoch - 6ms/step
# Epoch 62/100
# 185/185 - 1s - loss: 0.0219 - 1s/epoch - 7ms/step
# Epoch 63/100
# 185/185 - 1s - loss: 0.0217 - 1s/epoch - 7ms/step
# Epoch 64/100
# 185/185 - 1s - loss: 0.0220 - 1s/epoch - 7ms/step
# Epoch 65/100
# 185/185 - 1s - loss: 0.0221 - 1s/epoch - 7ms/step
# Epoch 66/100
# 185/185 - 1s - loss: 0.0220 - 1s/epoch - 6ms/step
# Epoch 67/100
# 185/185 - 1s - loss: 0.0220 - 1s/epoch - 6ms/step
# Epoch 68/100
# 185/185 - 1s - loss: 0.0220 - 1s/epoch - 6ms/step
# Epoch 69/100
# 185/185 - 1s - loss: 0.0217 - 1s/epoch - 6ms/step
# Epoch 70/100
# 185/185 - 1s - loss: 0.0219 - 1s/epoch - 6ms/step
# Epoch 71/100
# 185/185 - 1s - loss: 0.0219 - 1s/epoch - 6ms/step
# Epoch 72/100
# 185/185 - 1s - loss: 0.0218 - 1s/epoch - 6ms/step
# Epoch 73/100
# 185/185 - 1s - loss: 0.0216 - 1s/epoch - 6ms/step
# Epoch 74/100
# 185/185 - 1s - loss: 0.0221 - 1s/epoch - 6ms/step
# Epoch 75/100
# 185/185 - 1s - loss: 0.0218 - 1s/epoch - 6ms/step
# Epoch 76/100
# 185/185 - 1s - loss: 0.0218 - 1s/epoch - 6ms/step
# Epoch 77/100
# 185/185 - 1s - loss: 0.0221 - 1s/epoch - 6ms/step
# Epoch 78/100
# 185/185 - 2s - loss: 0.0221 - 2s/epoch - 8ms/step
# Epoch 79/100
# 185/185 - 2s - loss: 0.0218 - 2s/epoch - 9ms/step
# Epoch 80/100
# 185/185 - 2s - loss: 0.0221 - 2s/epoch - 9ms/step
# Epoch 81/100
# 185/185 - 2s - loss: 0.0219 - 2s/epoch - 10ms/step
# Epoch 82/100
# 185/185 - 2s - loss: 0.0221 - 2s/epoch - 9ms/step
# Epoch 83/100
# 185/185 - 2s - loss: 0.0220 - 2s/epoch - 10ms/step
# Epoch 84/100
# 185/185 - 2s - loss: 0.0219 - 2s/epoch - 8ms/step
# Epoch 85/100
# 185/185 - 1s - loss: 0.0218 - 1s/epoch - 6ms/step
# Epoch 86/100
# 185/185 - 1s - loss: 0.0216 - 1s/epoch - 6ms/step
# Epoch 87/100
# 185/185 - 1s - loss: 0.0221 - 1s/epoch - 6ms/step
# Epoch 88/100
# 185/185 - 1s - loss: 0.0220 - 1s/epoch - 6ms/step
# Epoch 89/100
# 185/185 - 1s - loss: 0.0221 - 1s/epoch - 6ms/step
# Epoch 90/100
# 185/185 - 2s - loss: 0.0219 - 2s/epoch - 8ms/step
# Epoch 91/100
# 185/185 - 2s - loss: 0.0220 - 2s/epoch - 9ms/step
# Epoch 92/100
# 185/185 - 2s - loss: 0.0219 - 2s/epoch - 9ms/step
# Epoch 93/100
# 185/185 - 2s - loss: 0.0219 - 2s/epoch - 10ms/step
# Epoch 94/100
# 185/185 - 2s - loss: 0.0221 - 2s/epoch - 11ms/step
# Epoch 95/100
# 185/185 - 2s - loss: 0.0220 - 2s/epoch - 10ms/step
# Epoch 96/100
# 185/185 - 1s - loss: 0.0218 - 1s/epoch - 7ms/step
# Epoch 97/100
# 185/185 - 1s - loss: 0.0220 - 1s/epoch - 5ms/step
# Epoch 98/100
# 185/185 - 1s - loss: 0.0218 - 1s/epoch - 7ms/step
# Epoch 99/100
# 185/185 - 2s - loss: 0.0220 - 2s/epoch - 9ms/step
# Epoch 100/100
# 185/185 - 2s - loss: 0.0219 - 2s/epoch - 9ms/step

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 6/6 [==============================] - 1s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# Train Score: 2.87 RMSE
# Test Score: 3.46 RMSE

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
