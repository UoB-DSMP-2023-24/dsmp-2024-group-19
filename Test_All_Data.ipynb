# %%
from tools import read_merged_data

# %%
test = read_merged_data(0)
# Out:
# Opening UoB_Set01_2025-01-02tapes.csv
# c:\Users\wwden\OneDrive\Documents\GitHub\dsmp-2024-group-19\tools.py:220: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_bids_asks = df_bids_asks.applymap(lambda x: x[1:-1].replace(",","") if isinstance(x, str) else "")
# c:\Users\wwden\OneDrive\Documents\GitHub\dsmp-2024-group-19\tools.py:249: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   resampled_df["Last Tapes Price"] = resampled_df["Tapes Price"].fillna(method = "ffill")

# %%
import matplotlib.pyplot as plt

for k in range(1):
    plt.figure(figsize=(20,5))
    plt.plot(test[k].index, test[k]["Tapes Price"])
    plt.show()
